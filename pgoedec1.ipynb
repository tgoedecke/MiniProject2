# %%
import sys
import re
import pymongo
import json
import time
import datetime
import requests
from bs4 import BeautifulSoup

dbname = "fdac18mp2" #please use this database
collname = "glprj_pgoedec1" #please modify so you store data in your collection
my_char = 'c'

# beginning page index
begin = "1"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


gitlab_url = "https://gitlab.com/api/v4/projects?archived=false&membership=false&order_by=created_at&owned=false&page=" + begin + \
    "&per_page=99&simple=false&sort=desc&starred=false&statistics=false&with_custom_attributes=false&with_issues_enabled=false&with_merge_requests_enabled=false"

gleft = 20

source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

# check remaining query chances for rate-limit restriction
def wait(left):
    global header
    while (left < 20):
        l = requests.get('https://gitlab.com/api/v4/projects', headers=header)
        if (l.ok):
            left = int(l.headers.get('RateLimit-Remaining'))
        time .sleep(60)
    return left

def project_exists(url):
    r = requests.get(url)
    if r.status_code == 200:
        return True
    return False

def get_source(url, coll, rest):
    page = 1
    project_count = 0
    while True:
        resp = requests.get(url + str(page))
        text = resp.text
        soup = BeautifulSoup(text, 'html.parser')
        if re.search('No results found.', soup.get_text()):
            return

        for link in soup.find_all(class_="project-icon", href=True):
            name = re.findall('/projects/([A-Za-z0-9\-]*)', link.get('href'))
            name = name[0] if name else None
            if name is not None and name.lower().startswith(my_char):
                resp = requests.get(rest + name)
                if resp.status_code == 200:
                    info = json.loads(resp.text)
                    info['forge'] = 'sourceforge'
                    coll.insert_one(info)
                    project_count += 1
                    if project_count >= 50:
                        return
        page += 1
    return

# send queries and extract urls 
def get_gitlab(url, coll):

    global gleft
    global header
    global bginnum
    gleft = wait(gleft)
    values = []
    size = 0
    project_count = 0

    try:
        r = requests .get(url, headers=header)
        time .sleep(0.5)
        # got blocked
        if r.status_code == 403:
            return "got blocked", str(bginnum)
        if (r.ok):

            gleft = int(r.headers.get('RateLimit-Remaining'))
            lll = r.headers.get('Link')
            t = r.text
            array = json.loads(t)
            
            for el in array:
                if el['name'].lower().startswith(my_char):
                    if project_exists(el['http_url_to_repo']):
                        project_count += 1
                        el['forge'] = 'gitlab'
                        coll.insert_one(el)
                        if project_count >= 50:
                            return
            
            #next page
            while ('; rel="next"' in lll):
                gleft = int(r.headers.get('RateLimit-Remaining'))
                gleft = wait(gleft)
                # extract next page url
                ll = lll.replace(';', ',').split(',')
                url = ll[ll.index(' rel="next"') -
                         1].replace('<', '').replace('>', '').lstrip()
             
                try:
                    r = requests .get(url, headers=header)
                    if r.status_code == 403:
                        return "got blocked", str(bginnum)
                    if (r.ok):
                        lll = r.headers.get('Link')
                        t = r.text
                        array1 = json.loads(t)
                        for el in array1:
                            if el['name'].lower().startswith(my_char):
                                if project_exists(el['http_url_to_repo']):
                                    project_count += 1
                                    el['forge'] = 'gitlab'
                                    coll.insert_one(el)
                                    if project_count >= 50:
                                        return
                    else:
                        sys.stderr.write("url can not found:\n" + url + '\n')
                        return 
                except requests.exceptions.ConnectionError:
                    sys.stderr.write('could not get ' + url + '\n')
            
        else:
            sys.stderr.write("url can not found:\n" + url + '\n')
            return

    except requests.exceptions.ConnectionError:
        sys.stderr.write('could not get ' + url + '\n')
    except Exception as e:
        sys.stderr.write(url + ';' + str(e) + '\n')
        
#start retrieving        
get_gitlab(gitlab_url,coll)
get_source(source_url, coll, rest_url)
#print collected data
for doc in coll.find({}):
    print(doc)
    
# entries.append(entry.copy())
# https://stackoverflow.com/questions/17529216/mongodb-insert-raises-duplicate-key-error
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-2-3dcbde6b530d> in <module>()
#     145 #start retrieving
#     146 get_gitlab(gitlab_url,coll)
# --> 147 get_source(source_url, coll, rest_url)
#     148 #print collected data
#     149 for doc in coll.find({}):
#
# <ipython-input-2-3dcbde6b530d> in get_source(url, coll, rest)
#      63                     info = json.loads(resp.text)
#      64                     info['forge'] = 'sourceforge'
# ---> 65                     coll.insert_one(info)
#      66                     project_count += 1
#      67                     if project_count >= 50:
#
# /usr/local/lib/python3.5/dist-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     691                          write_concern=write_concern,
#     692                          bypass_doc_val=bypass_document_validation,
# --> 693                          session=session),
#     694             write_concern.acknowledged)
#     695
#
# /usr/local/lib/python3.5/dist-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     605             return self._insert_one(
#     606                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 607                 bypass_doc_val, session)
#     608
#     609         ids = []
#
# /usr/local/lib/python3.5/dist-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     593
#     594         self.__database.client._retryable_write(
# --> 595             acknowledged, _insert_command, session)
#     596
#     597         if not isinstance(doc, RawBSONDocument):
#
# /usr/local/lib/python3.5/dist-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1241         """Internal retryable write helper."""
#    1242         with self._tmp_session(session) as s:
# -> 1243             return self._retry_with_session(retryable, func, s, None)
#    1244
#    1245     def __reset_server(self, address):
#
# /usr/local/lib/python3.5/dist-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1194                         # Reset the transaction id and retry the operation.
#    1195                         session._retry_transaction_id()
# -> 1196                     return func(session, sock_info, retryable)
#    1197             except ServerSelectionTimeoutError:
#    1198                 if is_retrying():
#
# /usr/local/lib/python3.5/dist-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     590                 retryable_write=retryable_write)
#     591
# --> 592             _check_write_command_response(result)
#     593
#     594         self.__database.client._retryable_write(
#
# /usr/local/lib/python3.5/dist-packages/pymongo/helpers.py in _check_write_command_response(result)
#     215     write_errors = result.get("writeErrors")
#     216     if write_errors:
# --> 217         _raise_last_write_error(write_errors)
#     218
#     219     error = result.get("writeConcernError")
#
# /usr/local/lib/python3.5/dist-packages/pymongo/helpers.py in _raise_last_write_error(write_errors)
#     196     error = write_errors[-1]
#     197     if error.get("code") == 11000:
# --> 198         raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     199     raise WriteError(error.get("errmsg"), error.get("code"), error)
#     200
#
# DuplicateKeyError: E11000 duplicate key error collection: fdac18mp2.glprj_pgoedec1 index: _id_ dup key: { : "515b2b0234309d2f211834ee" }

# %%
source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

collname = "sf_pgoedec1" #please modify so you store data in your collection
coll=db[collname]
get_source(source_url, coll, rest_url)

# %%
dbname = "fdac18mp2" #please use this database
collname = "glprj_pgoedec1" #please modify so you store data in your collection
my_char = 'c'

# beginning page index
begin = "1"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


for r in coll.find():
    print(r)
# Out:
# {'name': 'coreboot', 'description': '', 'namespace': {'full_path': 'savedRepo', 'name': 'savedRepo', 'kind': 'group', 'path': 'savedRepo', 'parent_id': None, 'id': 2418053}, 'path': 'coreboot', 'ssh_url_to_repo': 'git@gitlab.com:savedRepo/coreboot.git', 'id': 9187017, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d78f9d25c224b5875b3'), 'star_count': 0, 'name_with_namespace': 'savedRepo / coreboot', 'avatar_url': None, 'web_url': 'https://gitlab.com/savedRepo/coreboot', 'last_activity_at': '2018-11-02T18:27:54.918Z', 'http_url_to_repo': 'https://gitlab.com/savedRepo/coreboot.git', 'created_at': '2018-11-02T18:27:54.918Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/savedRepo/coreboot/blob/master/README.md', 'path_with_namespace': 'savedRepo/coreboot'}
# {'name': 'cmssystem', 'description': None, 'namespace': {'full_path': 'khanhhqse04966', 'name': 'khanhhqse04966', 'kind': 'user', 'path': 'khanhhqse04966', 'parent_id': None, 'id': 3931058}, 'path': 'cmssystem', 'ssh_url_to_repo': 'git@gitlab.com:khanhhqse04966/cmssystem.git', 'id': 9186973, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d78f9d25c224b5875b4'), 'star_count': 0, 'name_with_namespace': 'Hoang Quoc Khanh - K11 FUG HN / cmssystem', 'avatar_url': None, 'web_url': 'https://gitlab.com/khanhhqse04966/cmssystem', 'last_activity_at': '2018-11-02T18:23:57.272Z', 'http_url_to_repo': 'https://gitlab.com/khanhhqse04966/cmssystem.git', 'created_at': '2018-11-02T18:23:57.272Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'khanhhqse04966/cmssystem'}
# {'name': 'claw', 'description': 'C LAnguage Wrapper API Generator', 'namespace': {'full_path': 'sivachandra', 'name': 'sivachandra', 'kind': 'user', 'path': 'sivachandra', 'parent_id': None, 'id': 3652912}, 'path': 'claw', 'ssh_url_to_repo': 'git@gitlab.com:sivachandra/claw.git', 'id': 9186747, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d7df9d25c224b5875b5'), 'star_count': 0, 'name_with_namespace': 'Sivachandra Reddy / claw', 'avatar_url': None, 'web_url': 'https://gitlab.com/sivachandra/claw', 'last_activity_at': '2018-11-02T18:07:57.374Z', 'http_url_to_repo': 'https://gitlab.com/sivachandra/claw.git', 'created_at': '2018-11-02T18:07:57.374Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/sivachandra/claw/blob/master/README.md', 'path_with_namespace': 'sivachandra/claw'}
# {'name': 'cygnet', 'description': 'a linear probabilistic approach to modelling stellar spectra', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'cygnet', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/cygnet.git', 'id': 9186686, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d7ef9d25c224b5875b6'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / cygnet', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/cygnet', 'last_activity_at': '2018-11-02T18:05:59.533Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/cygnet.git', 'created_at': '2018-11-02T18:05:59.533Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/cygnet/blob/master/README.md', 'path_with_namespace': 'dwhogg/cygnet'}
# {'name': 'crushinator', 'description': 'inferring spectral properties at higher-than-observed resolution; deconvolving spectra', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'crushinator', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/crushinator.git', 'id': 9186684, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d7ef9d25c224b5875b7'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / crushinator', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/crushinator', 'last_activity_at': '2018-11-02T18:05:58.050Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/crushinator.git', 'created_at': '2018-11-02T18:05:58.050Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/crushinator/blob/master/README.md', 'path_with_namespace': 'dwhogg/crushinator'}
# {'name': 'CrossValidation', 'description': 'notes to share with Jake Vanderplas', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CrossValidation', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CrossValidation.git', 'id': 9186683, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d7ff9d25c224b5875b8'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CrossValidation', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CrossValidation', 'last_activity_at': '2018-11-02T18:05:56.692Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CrossValidation.git', 'created_at': '2018-11-02T18:05:56.692Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CrossValidation/blob/master/README.rst', 'path_with_namespace': 'dwhogg/CrossValidation'}
# {'name': 'CroMagnon', 'description': 'nothing to see here', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CroMagnon', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CroMagnon.git', 'id': 9186682, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d7ff9d25c224b5875b9'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CroMagnon', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CroMagnon', 'last_activity_at': '2018-11-02T18:05:54.780Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CroMagnon.git', 'created_at': '2018-11-02T18:05:54.780Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CroMagnon/blob/master/README.md', 'path_with_namespace': 'dwhogg/CroMagnon'}
# {'name': 'cosmography', 'description': "the new home for Hogg's (old, old) notes on distance measures in cosmology", 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'cosmography', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/cosmography.git', 'id': 9186681, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d7ff9d25c224b5875ba'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / cosmography', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/cosmography', 'last_activity_at': '2018-11-02T18:05:52.505Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/cosmography.git', 'created_at': '2018-11-02T18:05:52.505Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/cosmography/blob/master/README.md', 'path_with_namespace': 'dwhogg/cosmography'}
# {'name': 'CorrelationFunctionEstimator', 'description': 'changing cosmology and minds', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CorrelationFunctionEstimator', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CorrelationFunctionEstimator.git', 'id': 9186680, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d80f9d25c224b5875bb'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CorrelationFunctionEstimator', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CorrelationFunctionEstimator', 'last_activity_at': '2018-11-02T18:05:50.379Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CorrelationFunctionEstimator.git', 'created_at': '2018-11-02T18:05:50.379Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CorrelationFunctionEstimator/blob/master/README.md', 'path_with_namespace': 'dwhogg/CorrelationFunctionEstimator'}
# {'name': 'CoMiBaRaAn', 'description': 'joint spectral-energy-distribution and spatial priors for separating contributions to CMB maps', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CoMiBaRaAn', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CoMiBaRaAn.git', 'id': 9186679, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d80f9d25c224b5875bc'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CoMiBaRaAn', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CoMiBaRaAn', 'last_activity_at': '2018-11-02T18:05:48.825Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CoMiBaRaAn.git', 'created_at': '2018-11-02T18:05:48.825Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CoMiBaRaAn/blob/master/README.md', 'path_with_namespace': 'dwhogg/CoMiBaRaAn'}
# {'name': 'CombinatoricDegeneracies', 'description': 'a playground for defeating MCMC and evidence integrations', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CombinatoricDegeneracies', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CombinatoricDegeneracies.git', 'id': 9186678, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d81f9d25c224b5875bd'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CombinatoricDegeneracies', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CombinatoricDegeneracies', 'last_activity_at': '2018-11-02T18:05:47.338Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CombinatoricDegeneracies.git', 'created_at': '2018-11-02T18:05:47.338Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CombinatoricDegeneracies/blob/master/README.md', 'path_with_namespace': 'dwhogg/CombinatoricDegeneracies'}
# {'name': 'CoffeeTable', 'description': "build a front-projection glass coffee table in Hogg's Office", 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CoffeeTable', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CoffeeTable.git', 'id': 9186677, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d81f9d25c224b5875be'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CoffeeTable', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CoffeeTable', 'last_activity_at': '2018-11-02T18:05:45.828Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CoffeeTable.git', 'created_at': '2018-11-02T18:05:45.828Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CoffeeTable/blob/master/README.md', 'path_with_namespace': 'dwhogg/CoffeeTable'}
# {'name': 'ChemicalTangents', 'description': None, 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'ChemicalTangents', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/ChemicalTangents.git', 'id': 9186676, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d82f9d25c224b5875bf'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / ChemicalTangents', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/ChemicalTangents', 'last_activity_at': '2018-11-02T18:05:44.373Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/ChemicalTangents.git', 'created_at': '2018-11-02T18:05:44.373Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/ChemicalTangents/blob/master/README.md', 'path_with_namespace': 'dwhogg/ChemicalTangents'}
# {'name': 'CensoredData', 'description': 'working with data from a data provider no-one can trust', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CensoredData', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CensoredData.git', 'id': 9186675, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d82f9d25c224b5875c0'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CensoredData', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CensoredData', 'last_activity_at': '2018-11-02T18:05:42.338Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CensoredData.git', 'created_at': '2018-11-02T18:05:42.338Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CensoredData/blob/master/README.md', 'path_with_namespace': 'dwhogg/CensoredData'}
# {'name': 'CameraModel', 'description': 'exploratory code to model the E&M fields in a camera', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CameraModel', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CameraModel.git', 'id': 9186674, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d82f9d25c224b5875c1'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CameraModel', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CameraModel', 'last_activity_at': '2018-11-02T18:05:39.930Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CameraModel.git', 'created_at': '2018-11-02T18:05:39.930Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CameraModel/blob/master/README.md', 'path_with_namespace': 'dwhogg/CameraModel'}
# {'name': 'CalibrationTalk', 'description': 'self-calibration, explained', 'namespace': {'full_path': 'dwhogg', 'name': 'dwhogg', 'kind': 'user', 'path': 'dwhogg', 'parent_id': None, 'id': 3859768}, 'path': 'CalibrationTalk', 'ssh_url_to_repo': 'git@gitlab.com:dwhogg/CalibrationTalk.git', 'id': 9186673, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d83f9d25c224b5875c2'), 'star_count': 0, 'name_with_namespace': 'David W Hogg / CalibrationTalk', 'avatar_url': None, 'web_url': 'https://gitlab.com/dwhogg/CalibrationTalk', 'last_activity_at': '2018-11-02T18:05:38.320Z', 'http_url_to_repo': 'https://gitlab.com/dwhogg/CalibrationTalk.git', 'created_at': '2018-11-02T18:05:38.320Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/dwhogg/CalibrationTalk/blob/master/README.md', 'path_with_namespace': 'dwhogg/CalibrationTalk'}
# {'name': 'cg5', 'description': '', 'namespace': {'full_path': 'v9gel', 'name': 'v9gel', 'kind': 'user', 'path': 'v9gel', 'parent_id': None, 'id': 3856293}, 'path': 'cg5', 'ssh_url_to_repo': 'git@gitlab.com:v9gel/cg5.git', 'id': 9186463, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d89f9d25c224b5875c3'), 'star_count': 0, 'name_with_namespace': 'Вячеслав Нагель / cg5', 'avatar_url': None, 'web_url': 'https://gitlab.com/v9gel/cg5', 'last_activity_at': '2018-11-02T17:48:19.053Z', 'http_url_to_repo': 'https://gitlab.com/v9gel/cg5.git', 'created_at': '2018-11-02T17:48:19.053Z', 'default_branch': None, 'readme_url': None, 'path_with_namespace': 'v9gel/cg5'}
# {'name': 'cs6161_final', 'description': 'Final project for CS6161 2013 Spring', 'namespace': {'full_path': 'liangwang', 'name': 'liangwang', 'kind': 'user', 'path': 'liangwang', 'parent_id': None, 'id': 57006}, 'path': 'cs6161_final', 'ssh_url_to_repo': 'git@gitlab.com:liangwang/cs6161_final.git', 'id': 9186442, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d89f9d25c224b5875c4'), 'star_count': 0, 'name_with_namespace': 'Liang Wang / cs6161_final', 'avatar_url': None, 'web_url': 'https://gitlab.com/liangwang/cs6161_final', 'last_activity_at': '2018-11-02T17:46:40.100Z', 'http_url_to_repo': 'https://gitlab.com/liangwang/cs6161_final.git', 'created_at': '2018-11-02T17:46:40.100Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/liangwang/cs6161_final/blob/master/README.rst', 'path_with_namespace': 'liangwang/cs6161_final'}
# {'name': 'condatfgpu_docker', 'description': 'Anaconda3 + TF 1.3 Docker', 'namespace': {'full_path': 'liangwang', 'name': 'liangwang', 'kind': 'user', 'path': 'liangwang', 'parent_id': None, 'id': 57006}, 'path': 'condatfgpu_docker', 'ssh_url_to_repo': 'git@gitlab.com:liangwang/condatfgpu_docker.git', 'id': 9186441, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8af9d25c224b5875c5'), 'star_count': 0, 'name_with_namespace': 'Liang Wang / condatfgpu_docker', 'avatar_url': None, 'web_url': 'https://gitlab.com/liangwang/condatfgpu_docker', 'last_activity_at': '2018-11-02T17:46:37.979Z', 'http_url_to_repo': 'https://gitlab.com/liangwang/condatfgpu_docker.git', 'created_at': '2018-11-02T17:46:37.979Z', 'default_branch': None, 'readme_url': None, 'path_with_namespace': 'liangwang/condatfgpu_docker'}
# {'name': 'coding-interview-university', 'description': 'A complete computer science study plan to become a software engineer.', 'namespace': {'full_path': 'liangwang', 'name': 'liangwang', 'kind': 'user', 'path': 'liangwang', 'parent_id': None, 'id': 57006}, 'path': 'coding-interview-university', 'ssh_url_to_repo': 'git@gitlab.com:liangwang/coding-interview-university.git', 'id': 9186440, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8af9d25c224b5875c6'), 'star_count': 0, 'name_with_namespace': 'Liang Wang / coding-interview-university', 'avatar_url': None, 'web_url': 'https://gitlab.com/liangwang/coding-interview-university', 'last_activity_at': '2018-11-02T17:46:35.315Z', 'http_url_to_repo': 'https://gitlab.com/liangwang/coding-interview-university.git', 'created_at': '2018-11-02T17:46:35.315Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/liangwang/coding-interview-university/blob/master/README.md', 'path_with_namespace': 'liangwang/coding-interview-university'}
# {'name': 'cg1', 'description': None, 'namespace': {'full_path': 'v9gel', 'name': 'v9gel', 'kind': 'user', 'path': 'v9gel', 'parent_id': None, 'id': 3856293}, 'path': 'cg1', 'ssh_url_to_repo': 'git@gitlab.com:v9gel/cg1.git', 'id': 9186427, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8af9d25c224b5875c7'), 'star_count': 0, 'name_with_namespace': 'Вячеслав Нагель / cg1', 'avatar_url': None, 'web_url': 'https://gitlab.com/v9gel/cg1', 'last_activity_at': '2018-11-02T17:45:23.962Z', 'http_url_to_repo': 'https://gitlab.com/v9gel/cg1.git', 'created_at': '2018-11-02T17:45:23.962Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'v9gel/cg1'}
# {'name': 'calligra', 'description': '', 'namespace': {'full_path': 'savedRepo', 'name': 'savedRepo', 'kind': 'group', 'path': 'savedRepo', 'parent_id': None, 'id': 2418053}, 'path': 'calligra', 'ssh_url_to_repo': 'git@gitlab.com:savedRepo/calligra.git', 'id': 9186424, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8bf9d25c224b5875c8'), 'star_count': 0, 'name_with_namespace': 'savedRepo / calligra', 'avatar_url': None, 'web_url': 'https://gitlab.com/savedRepo/calligra', 'last_activity_at': '2018-11-02T17:45:13.669Z', 'http_url_to_repo': 'https://gitlab.com/savedRepo/calligra.git', 'created_at': '2018-11-02T17:45:13.669Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/savedRepo/calligra/blob/master/README', 'path_with_namespace': 'savedRepo/calligra'}
# {'name': 'compiladores', 'description': '', 'namespace': {'full_path': 'cquispeq', 'name': 'cquispeq', 'kind': 'user', 'path': 'cquispeq', 'parent_id': None, 'id': 2495916}, 'path': 'compiladores', 'ssh_url_to_repo': 'git@gitlab.com:cquispeq/compiladores.git', 'id': 9186384, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8bf9d25c224b5875c9'), 'star_count': 0, 'name_with_namespace': 'Cristhian Quispe / compiladores', 'avatar_url': None, 'web_url': 'https://gitlab.com/cquispeq/compiladores', 'last_activity_at': '2018-11-02T17:41:06.337Z', 'http_url_to_repo': 'https://gitlab.com/cquispeq/compiladores.git', 'created_at': '2018-11-02T17:41:06.337Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'cquispeq/compiladores'}
# {'name': 'CappuchinoSite', 'description': '', 'namespace': {'full_path': 'Cappuchino', 'name': 'Cappuchino', 'kind': 'user', 'path': 'Cappuchino', 'parent_id': None, 'id': 3495509}, 'path': 'cappuchinosite', 'ssh_url_to_repo': 'git@gitlab.com:Cappuchino/cappuchinosite.git', 'id': 9186265, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8cf9d25c224b5875ca'), 'star_count': 0, 'name_with_namespace': 'Pornpipat Popum / CappuchinoSite', 'avatar_url': None, 'web_url': 'https://gitlab.com/Cappuchino/cappuchinosite', 'last_activity_at': '2018-11-02T17:26:41.670Z', 'http_url_to_repo': 'https://gitlab.com/Cappuchino/cappuchinosite.git', 'created_at': '2018-11-02T17:26:41.670Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/Cappuchino/cappuchinosite/blob/master/README.md', 'path_with_namespace': 'Cappuchino/cappuchinosite'}
# {'name': 'cdk', 'description': 'Cloud Development Toolkit', 'namespace': {'full_path': 'padde-aws', 'name': 'Paddes AWS', 'kind': 'group', 'path': 'padde-aws', 'parent_id': None, 'id': 2786169}, 'path': 'cdk', 'ssh_url_to_repo': 'git@gitlab.com:padde-aws/cdk.git', 'id': 9185938, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d8cf9d25c224b5875cb'), 'star_count': 0, 'name_with_namespace': 'Paddes AWS / cdk', 'avatar_url': None, 'web_url': 'https://gitlab.com/padde-aws/cdk', 'last_activity_at': '2018-11-02T16:55:52.549Z', 'http_url_to_repo': 'https://gitlab.com/padde-aws/cdk.git', 'created_at': '2018-11-02T16:55:52.549Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/padde-aws/cdk/blob/master/README.md', 'path_with_namespace': 'padde-aws/cdk'}
# {'name': 'cv', 'description': 'Publicação do projeto cvbackend', 'namespace': {'full_path': 'knowmoreaboutme', 'name': 'knowmoreaboutme', 'kind': 'group', 'path': 'knowmoreaboutme', 'parent_id': None, 'id': 3618887}, 'path': 'cv', 'ssh_url_to_repo': 'git@gitlab.com:knowmoreaboutme/cv.git', 'id': 9185762, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d92f9d25c224b5875cc'), 'star_count': 0, 'name_with_namespace': 'knowmoreaboutme / cv', 'avatar_url': None, 'web_url': 'https://gitlab.com/knowmoreaboutme/cv', 'last_activity_at': '2018-11-02T18:52:44.240Z', 'http_url_to_repo': 'https://gitlab.com/knowmoreaboutme/cv.git', 'created_at': '2018-11-02T16:41:05.830Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/knowmoreaboutme/cv/blob/master/README.md', 'path_with_namespace': 'knowmoreaboutme/cv'}
# {'name': 'Creative Theme', 'description': 'A Jekyll implementation of the [Creative Theme](http://startbootstrap.com/template-overviews/creative/) template by [Start Bootstrap](http://startbootstrap.com/)', 'namespace': {'full_path': 'circuito-ajedrez', 'name': 'circuito-ajedrez', 'kind': 'group', 'path': 'circuito-ajedrez', 'parent_id': None, 'id': 3820137}, 'path': 'creative', 'ssh_url_to_repo': 'git@gitlab.com:circuito-ajedrez/creative.git', 'id': 9185743, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d92f9d25c224b5875cd'), 'star_count': 0, 'name_with_namespace': 'circuito-ajedrez / Creative Theme', 'avatar_url': None, 'web_url': 'https://gitlab.com/circuito-ajedrez/creative', 'last_activity_at': '2018-11-02T16:39:34.064Z', 'http_url_to_repo': 'https://gitlab.com/circuito-ajedrez/creative.git', 'created_at': '2018-11-02T16:39:34.064Z', 'default_branch': 'pages', 'readme_url': 'https://gitlab.com/circuito-ajedrez/creative/blob/pages/README.md', 'path_with_namespace': 'circuito-ajedrez/creative'}
# {'name': 'crudUsers', 'description': '', 'namespace': {'full_path': 'dcgroen17', 'name': 'dcgroen17', 'kind': 'user', 'path': 'dcgroen17', 'parent_id': None, 'id': 3930707}, 'path': 'crudusers', 'ssh_url_to_repo': 'git@gitlab.com:dcgroen17/crudusers.git', 'id': 9185696, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d92f9d25c224b5875ce'), 'star_count': 0, 'name_with_namespace': 'Dion Groen / crudUsers', 'avatar_url': None, 'web_url': 'https://gitlab.com/dcgroen17/crudusers', 'last_activity_at': '2018-11-02T16:36:04.697Z', 'http_url_to_repo': 'https://gitlab.com/dcgroen17/crudusers.git', 'created_at': '2018-11-02T16:36:04.697Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'dcgroen17/crudusers'}
# {'name': 'Challenge 4', 'description': '', 'namespace': {'full_path': 'Julien-Baylac', 'name': 'Julien-Baylac', 'kind': 'user', 'path': 'Julien-Baylac', 'parent_id': None, 'id': 3717987}, 'path': 'challenge-4', 'ssh_url_to_repo': 'git@gitlab.com:Julien-Baylac/challenge-4.git', 'id': 9185694, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d93f9d25c224b5875cf'), 'star_count': 0, 'name_with_namespace': 'Julien Baylac / Challenge 4', 'avatar_url': None, 'web_url': 'https://gitlab.com/Julien-Baylac/challenge-4', 'last_activity_at': '2018-11-02T16:35:52.016Z', 'http_url_to_repo': 'https://gitlab.com/Julien-Baylac/challenge-4.git', 'created_at': '2018-11-02T16:35:52.016Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'Julien-Baylac/challenge-4'}
# {'name': 'cfd-common-roles', 'description': 'A set of common ansible roles I use frequently for webservers.', 'namespace': {'full_path': 'kjpc-tech', 'name': 'kjpc-tech', 'kind': 'user', 'path': 'kjpc-tech', 'parent_id': None, 'id': 1538271}, 'path': 'cfd-common-roles', 'ssh_url_to_repo': 'git@gitlab.com:kjpc-tech/cfd-common-roles.git', 'id': 9184998, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d93f9d25c224b5875d0'), 'star_count': 0, 'name_with_namespace': 'Kyle / cfd-common-roles', 'avatar_url': None, 'web_url': 'https://gitlab.com/kjpc-tech/cfd-common-roles', 'last_activity_at': '2018-11-02T17:19:08.226Z', 'http_url_to_repo': 'https://gitlab.com/kjpc-tech/cfd-common-roles.git', 'created_at': '2018-11-02T15:43:21.558Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/kjpc-tech/cfd-common-roles/blob/master/README.md', 'path_with_namespace': 'kjpc-tech/cfd-common-roles'}
# {'name': 'chef-docker', 'description': 'Install Docker', 'namespace': {'full_path': 'julienlevasseur', 'name': 'julienlevasseur', 'kind': 'user', 'path': 'julienlevasseur', 'parent_id': None, 'id': 2979492}, 'path': 'chef-docker', 'ssh_url_to_repo': 'git@gitlab.com:julienlevasseur/chef-docker.git', 'id': 9184959, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d94f9d25c224b5875d1'), 'star_count': 0, 'name_with_namespace': 'Julien Levasseur / chef-docker', 'avatar_url': None, 'web_url': 'https://gitlab.com/julienlevasseur/chef-docker', 'last_activity_at': '2018-11-02T17:53:17.572Z', 'http_url_to_repo': 'https://gitlab.com/julienlevasseur/chef-docker.git', 'created_at': '2018-11-02T15:40:21.430Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/julienlevasseur/chef-docker/blob/master/README.md', 'path_with_namespace': 'julienlevasseur/chef-docker'}
# {'name': 'cmph', 'description': 'C Minimal Perfect Hashing Library (imported from https://sourceforge.net/projects/cmph)', 'namespace': {'full_path': 'mtrenkmann', 'name': 'mtrenkmann', 'kind': 'user', 'path': 'mtrenkmann', 'parent_id': None, 'id': 1889700}, 'path': 'cmph', 'ssh_url_to_repo': 'git@gitlab.com:mtrenkmann/cmph.git', 'id': 9184930, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d94f9d25c224b5875d2'), 'star_count': 0, 'name_with_namespace': 'Martin Trenkmann / cmph', 'avatar_url': None, 'web_url': 'https://gitlab.com/mtrenkmann/cmph', 'last_activity_at': '2018-11-02T18:23:12.234Z', 'http_url_to_repo': 'https://gitlab.com/mtrenkmann/cmph.git', 'created_at': '2018-11-02T15:38:46.046Z', 'default_branch': 'minimal', 'readme_url': 'https://gitlab.com/mtrenkmann/cmph/blob/minimal/README.md', 'path_with_namespace': 'mtrenkmann/cmph'}
# {'name': 'CSE 4701 - Project 2 Part 1', 'description': '', 'namespace': {'full_path': 'Zyian', 'name': 'Zyian', 'kind': 'user', 'path': 'Zyian', 'parent_id': None, 'id': 1524766}, 'path': 'cse-4701-proj2', 'ssh_url_to_repo': 'git@gitlab.com:Zyian/cse-4701-proj2.git', 'id': 9184654, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d99f9d25c224b5875d3'), 'star_count': 0, 'name_with_namespace': 'Adrian Zygadlo / CSE 4701 - Project 2 Part 1', 'avatar_url': None, 'web_url': 'https://gitlab.com/Zyian/cse-4701-proj2', 'last_activity_at': '2018-11-02T15:17:39.304Z', 'http_url_to_repo': 'https://gitlab.com/Zyian/cse-4701-proj2.git', 'created_at': '2018-11-02T15:17:39.304Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'Zyian/cse-4701-proj2'}
# {'name': 'CaesarTest', 'description': '', 'namespace': {'full_path': 'Dp-149TAQC', 'name': 'Dp-149TAQC', 'kind': 'group', 'path': 'Dp-149TAQC', 'parent_id': None, 'id': 3930159}, 'path': 'caesartest', 'ssh_url_to_repo': 'git@gitlab.com:Dp-149TAQC/caesartest.git', 'id': 9184523, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9af9d25c224b5875d4'), 'star_count': 0, 'name_with_namespace': 'Dp-149TAQC / CaesarTest', 'avatar_url': None, 'web_url': 'https://gitlab.com/Dp-149TAQC/caesartest', 'last_activity_at': '2018-11-02T17:41:00.582Z', 'http_url_to_repo': 'https://gitlab.com/Dp-149TAQC/caesartest.git', 'created_at': '2018-11-02T15:07:22.425Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'Dp-149TAQC/caesartest'}
# {'name': 'ckan-mirror', 'description': '', 'namespace': {'full_path': 'amiedes', 'name': 'amiedes', 'kind': 'user', 'path': 'amiedes', 'parent_id': None, 'id': 2850279}, 'path': 'ckan-mirror', 'ssh_url_to_repo': 'git@gitlab.com:amiedes/ckan-mirror.git', 'id': 9184373, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9af9d25c224b5875d5'), 'star_count': 0, 'name_with_namespace': 'Alberto Miedes / ckan-mirror', 'avatar_url': None, 'web_url': 'https://gitlab.com/amiedes/ckan-mirror', 'last_activity_at': '2018-11-02T14:54:36.272Z', 'http_url_to_repo': 'https://gitlab.com/amiedes/ckan-mirror.git', 'created_at': '2018-11-02T14:54:36.272Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/amiedes/ckan-mirror/blob/master/README.rst', 'path_with_namespace': 'amiedes/ckan-mirror'}
# {'name': 'cookbook-guide-generator', 'description': '', 'namespace': {'full_path': 'julienlevasseur', 'name': 'julienlevasseur', 'kind': 'user', 'path': 'julienlevasseur', 'parent_id': None, 'id': 2979492}, 'path': 'cookbook-guide-generator', 'ssh_url_to_repo': 'git@gitlab.com:julienlevasseur/cookbook-guide-generator.git', 'id': 9184324, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9af9d25c224b5875d6'), 'star_count': 0, 'name_with_namespace': 'Julien Levasseur / cookbook-guide-generator', 'avatar_url': None, 'web_url': 'https://gitlab.com/julienlevasseur/cookbook-guide-generator', 'last_activity_at': '2018-11-02T14:51:06.580Z', 'http_url_to_repo': 'https://gitlab.com/julienlevasseur/cookbook-guide-generator.git', 'created_at': '2018-11-02T14:51:06.580Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/julienlevasseur/cookbook-guide-generator/blob/master/README.md', 'path_with_namespace': 'julienlevasseur/cookbook-guide-generator'}
# {'name': 'conFusion', 'description': 'conFusion is an assignment by Wiredelta, which focuses on how to use Bootstrap for styling. ', 'namespace': {'full_path': 'codeName_KC', 'name': 'codeName_KC', 'kind': 'user', 'path': 'codeName_KC', 'parent_id': None, 'id': 3861762}, 'path': 'confusion', 'ssh_url_to_repo': 'git@gitlab.com:codeName_KC/confusion.git', 'id': 9184205, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9bf9d25c224b5875d7'), 'star_count': 0, 'name_with_namespace': 'Kacey Okafor / conFusion', 'avatar_url': None, 'web_url': 'https://gitlab.com/codeName_KC/confusion', 'last_activity_at': '2018-11-02T14:42:30.185Z', 'http_url_to_repo': 'https://gitlab.com/codeName_KC/confusion.git', 'created_at': '2018-11-02T14:42:30.185Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'codeName_KC/confusion'}
# {'name': 'cartoon', 'description': 'Tried to cartoonize live video using opencv,', 'namespace': {'full_path': 'sharanp98', 'name': 'sharanp98', 'kind': 'user', 'path': 'sharanp98', 'parent_id': None, 'id': 2607957}, 'path': 'cartoon', 'ssh_url_to_repo': 'git@gitlab.com:sharanp98/cartoon.git', 'id': 9184192, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9bf9d25c224b5875d8'), 'star_count': 0, 'name_with_namespace': 'Sharan / cartoon', 'avatar_url': None, 'web_url': 'https://gitlab.com/sharanp98/cartoon', 'last_activity_at': '2018-11-02T14:41:56.715Z', 'http_url_to_repo': 'https://gitlab.com/sharanp98/cartoon.git', 'created_at': '2018-11-02T14:41:56.715Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/sharanp98/cartoon/blob/master/README.md', 'path_with_namespace': 'sharanp98/cartoon'}
# {'name': 'celcabs', 'description': None, 'namespace': {'full_path': 'sharanp98', 'name': 'sharanp98', 'kind': 'user', 'path': 'sharanp98', 'parent_id': None, 'id': 2607957}, 'path': 'celcabs', 'ssh_url_to_repo': 'git@gitlab.com:sharanp98/celcabs.git', 'id': 9184188, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9cf9d25c224b5875d9'), 'star_count': 0, 'name_with_namespace': 'Sharan / celcabs', 'avatar_url': None, 'web_url': 'https://gitlab.com/sharanp98/celcabs', 'last_activity_at': '2018-11-02T14:41:55.973Z', 'http_url_to_repo': 'https://gitlab.com/sharanp98/celcabs.git', 'created_at': '2018-11-02T14:41:55.973Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/sharanp98/celcabs/blob/master/README.md', 'path_with_namespace': 'sharanp98/celcabs'}
# {'name': 'cours uvt MP2L 2018_2019', 'description': '', 'namespace': {'full_path': 'oussama-ht', 'name': 'oussama-ht', 'kind': 'user', 'path': 'oussama-ht', 'parent_id': None, 'id': 1802479}, 'path': 'cours-uvt-mp2l-2018_2019', 'ssh_url_to_repo': 'git@gitlab.com:oussama-ht/cours-uvt-mp2l-2018_2019.git', 'id': 9184029, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9cf9d25c224b5875da'), 'star_count': 0, 'name_with_namespace': 'oussama / cours uvt MP2L 2018_2019', 'avatar_url': None, 'web_url': 'https://gitlab.com/oussama-ht/cours-uvt-mp2l-2018_2019', 'last_activity_at': '2018-11-02T14:30:29.802Z', 'http_url_to_repo': 'https://gitlab.com/oussama-ht/cours-uvt-mp2l-2018_2019.git', 'created_at': '2018-11-02T14:30:29.802Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'oussama-ht/cours-uvt-mp2l-2018_2019'}
# {'name': 'CinemaApp', 'description': 'Our first cinema project', 'namespace': {'full_path': 'silchencko', 'name': 'silchencko', 'kind': 'user', 'path': 'silchencko', 'parent_id': None, 'id': 3929827}, 'path': 'cinemaapp', 'ssh_url_to_repo': 'git@gitlab.com:silchencko/cinemaapp.git', 'id': 9183994, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9df9d25c224b5875db'), 'star_count': 0, 'name_with_namespace': 'Kateryna / CinemaApp', 'avatar_url': None, 'web_url': 'https://gitlab.com/silchencko/cinemaapp', 'last_activity_at': '2018-11-02T14:28:54.433Z', 'http_url_to_repo': 'https://gitlab.com/silchencko/cinemaapp.git', 'created_at': '2018-11-02T14:28:54.433Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/silchencko/cinemaapp/blob/master/README.md', 'path_with_namespace': 'silchencko/cinemaapp'}
# {'name': 'Compilation_Principle', 'description': '编译原理课程相关程序', 'namespace': {'full_path': 'pornbusiness', 'name': 'pornbusiness', 'kind': 'user', 'path': 'pornbusiness', 'parent_id': None, 'id': 3670922}, 'path': 'Compilation_Principle', 'ssh_url_to_repo': 'git@gitlab.com:pornbusiness/Compilation_Principle.git', 'id': 9183930, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9d9df9d25c224b5875dc'), 'star_count': 0, 'name_with_namespace': 'pornbusinessman / Compilation_Principle', 'avatar_url': None, 'web_url': 'https://gitlab.com/pornbusiness/Compilation_Principle', 'last_activity_at': '2018-11-02T14:23:15.975Z', 'http_url_to_repo': 'https://gitlab.com/pornbusiness/Compilation_Principle.git', 'created_at': '2018-11-02T14:23:15.975Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'pornbusiness/Compilation_Principle'}
# {'name': 'Campylobacter microsimulation', 'description': '', 'namespace': {'full_path': 'rasanderson', 'name': 'rasanderson', 'kind': 'user', 'path': 'rasanderson', 'parent_id': None, 'id': 499737}, 'path': 'campylobacter-microsimulation', 'ssh_url_to_repo': 'git@gitlab.com:rasanderson/campylobacter-microsimulation.git', 'id': 9183697, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da3f9d25c224b5875dd'), 'star_count': 0, 'name_with_namespace': 'Roy Sanderson / Campylobacter microsimulation', 'avatar_url': None, 'web_url': 'https://gitlab.com/rasanderson/campylobacter-microsimulation', 'last_activity_at': '2018-11-02T14:12:01.585Z', 'http_url_to_repo': 'https://gitlab.com/rasanderson/campylobacter-microsimulation.git', 'created_at': '2018-11-02T14:12:01.585Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/rasanderson/campylobacter-microsimulation/blob/master/README.md', 'path_with_namespace': 'rasanderson/campylobacter-microsimulation'}
# {'name': 'Cau_truc_du_ lieu_va_giai_thuat_nang_cao', 'description': '', 'namespace': {'full_path': '16521118', 'name': '16521118', 'kind': 'user', 'path': '16521118', 'parent_id': None, 'id': 2651391}, 'path': 'cau_truc_du_-lieu_va_giai_thuat_nang_cao', 'ssh_url_to_repo': 'git@gitlab.com:16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao.git', 'id': 9183585, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da3f9d25c224b5875de'), 'star_count': 0, 'name_with_namespace': 'THANH NGUYEN CHI / Cau_truc_du_ lieu_va_giai_thuat_nang_cao', 'avatar_url': None, 'web_url': 'https://gitlab.com/16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao', 'last_activity_at': '2018-11-02T14:04:33.746Z', 'http_url_to_repo': 'https://gitlab.com/16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao.git', 'created_at': '2018-11-02T14:04:33.746Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': '16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao'}
# {'name': 'CinemaApp', 'description': 'Our first cinema project', 'namespace': {'full_path': 'OlehRybalka', 'name': 'OlehRybalka', 'kind': 'user', 'path': 'OlehRybalka', 'parent_id': None, 'id': 3929712}, 'path': 'cinemaapp', 'ssh_url_to_repo': 'git@gitlab.com:OlehRybalka/cinemaapp.git', 'id': 9183565, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 1, '_id': ObjectId('5bdc9da4f9d25c224b5875df'), 'star_count': 0, 'name_with_namespace': 'OlehRybalka / CinemaApp', 'avatar_url': None, 'web_url': 'https://gitlab.com/OlehRybalka/cinemaapp', 'last_activity_at': '2018-11-02T14:02:26.648Z', 'http_url_to_repo': 'https://gitlab.com/OlehRybalka/cinemaapp.git', 'created_at': '2018-11-02T14:02:26.648Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/OlehRybalka/cinemaapp/blob/master/README.md', 'path_with_namespace': 'OlehRybalka/cinemaapp'}
# {'name': 'conceptual-web-extension', 'description': '', 'namespace': {'full_path': 'Conceptual-Learning', 'name': 'Conceptual', 'kind': 'group', 'path': 'Conceptual-Learning', 'parent_id': None, 'id': 3612867}, 'path': 'conceptual-web-extension', 'ssh_url_to_repo': 'git@gitlab.com:Conceptual-Learning/conceptual-web-extension.git', 'id': 9183526, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da4f9d25c224b5875e0'), 'star_count': 0, 'name_with_namespace': 'Conceptual / conceptual-web-extension', 'avatar_url': None, 'web_url': 'https://gitlab.com/Conceptual-Learning/conceptual-web-extension', 'last_activity_at': '2018-11-02T13:59:33.535Z', 'http_url_to_repo': 'https://gitlab.com/Conceptual-Learning/conceptual-web-extension.git', 'created_at': '2018-11-02T13:59:33.535Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/Conceptual-Learning/conceptual-web-extension/blob/master/README.md', 'path_with_namespace': 'Conceptual-Learning/conceptual-web-extension'}
# {'name': 'ClimbingStairs', 'description': '', 'namespace': {'full_path': 'a.g-h', 'name': 'a.g-h', 'kind': 'user', 'path': 'a.g-h', 'parent_id': None, 'id': 2014859}, 'path': 'climbingstairs', 'ssh_url_to_repo': 'git@gitlab.com:a.g-h/climbingstairs.git', 'id': 9183409, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da5f9d25c224b5875e1'), 'star_count': 0, 'name_with_namespace': 'Akihiro Gaevsky-Hanada / ClimbingStairs', 'avatar_url': None, 'web_url': 'https://gitlab.com/a.g-h/climbingstairs', 'last_activity_at': '2018-11-02T13:51:38.195Z', 'http_url_to_repo': 'https://gitlab.com/a.g-h/climbingstairs.git', 'created_at': '2018-11-02T13:51:38.195Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'a.g-h/climbingstairs'}
# {'name': 'cj1', 'description': 'Dev Technology Codejam 1', 'namespace': {'full_path': 'gzson79', 'name': 'gzson79', 'kind': 'user', 'path': 'gzson79', 'parent_id': None, 'id': 2175736}, 'path': 'cj1', 'ssh_url_to_repo': 'git@gitlab.com:gzson79/cj1.git', 'id': 9183260, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da5f9d25c224b5875e2'), 'star_count': 0, 'name_with_namespace': 'Sean / cj1', 'avatar_url': None, 'web_url': 'https://gitlab.com/gzson79/cj1', 'last_activity_at': '2018-11-02T15:01:06.259Z', 'http_url_to_repo': 'https://gitlab.com/gzson79/cj1.git', 'created_at': '2018-11-02T13:38:35.676Z', 'default_branch': None, 'readme_url': None, 'path_with_namespace': 'gzson79/cj1'}
# {'name': 'CarbonFootprint-Mobile', 'description': "A hybrid mobile application developed using React Native to calculate amount of emitted co2 based on user's activity", 'namespace': {'full_path': 'sagar-kalra', 'name': 'sagar-kalra', 'kind': 'user', 'path': 'sagar-kalra', 'parent_id': None, 'id': 3249692}, 'path': 'CarbonFootprint-Mobile', 'ssh_url_to_repo': 'git@gitlab.com:sagar-kalra/CarbonFootprint-Mobile.git', 'id': 9183072, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da5f9d25c224b5875e3'), 'star_count': 0, 'name_with_namespace': 'Sagar Kalra / CarbonFootprint-Mobile', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/9183072/globe-256.png', 'web_url': 'https://gitlab.com/sagar-kalra/CarbonFootprint-Mobile', 'last_activity_at': '2018-11-02T13:24:49.973Z', 'http_url_to_repo': 'https://gitlab.com/sagar-kalra/CarbonFootprint-Mobile.git', 'created_at': '2018-11-02T13:24:49.973Z', 'default_branch': 'master', 'readme_url': 'https://gitlab.com/sagar-kalra/CarbonFootprint-Mobile/blob/master/README.md', 'path_with_namespace': 'sagar-kalra/CarbonFootprint-Mobile'}
# {'name': 'crowdstarter', 'description': 'for team waymo', 'namespace': {'full_path': 'tobbyGitlab', 'name': 'tobbyGitlab', 'kind': 'user', 'path': 'tobbyGitlab', 'parent_id': None, 'id': 3106595}, 'path': 'crowdstarter', 'ssh_url_to_repo': 'git@gitlab.com:tobbyGitlab/crowdstarter.git', 'id': 9183045, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9da6f9d25c224b5875e4'), 'star_count': 0, 'name_with_namespace': 'Tobi / crowdstarter', 'avatar_url': None, 'web_url': 'https://gitlab.com/tobbyGitlab/crowdstarter', 'last_activity_at': '2018-11-02T13:23:34.403Z', 'http_url_to_repo': 'https://gitlab.com/tobbyGitlab/crowdstarter.git', 'created_at': '2018-11-02T13:23:34.403Z', 'default_branch': 'master', 'readme_url': None, 'path_with_namespace': 'tobbyGitlab/crowdstarter'}
# {'name': ' Car Racing Project 2010 ', 'labels': [], 'url': 'https://sourceforge.net/p/carracingprojec/', 'preferred_support_tool': '', 'screenshots': [{'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220836.jpg', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220836.jpg/thumb', 'caption': 'FinishLine on track 1'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220842.jpg', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220842.jpg/thumb', 'caption': 'Second Track Begining'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220834.jpg', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220834.jpg/thumb', 'caption': 'Begining of race on Track 1'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220832.jpg', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220832.jpg/thumb', 'caption': 'The Screen where you select a Track'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220846.jpg', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220846.jpg/thumb', 'caption': 'Startup Screen'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220848.jpg', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220848.jpg/thumb', 'caption': 'Select car'}], 'forge': 'sourceforge', '_id': '515b2b0234309d2f211834ee', 'creation_date': '2009-06-23', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'This project involves car race where one has to get to the finishing point before the given time elapses. The project is an open source and any is allow to develop on it.', 'moved_to_url': '', 'external_homepage': 'https://carracingprojec.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Calvin Marqques Omondi', 'url': 'https://sourceforge.net/u/marqquez03/', 'username': 'marqquez03'}], 'tools': [{'name': 'wiki', 'installable': True, 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'url': '/p/carracingprojec/wiki/', 'mount_label': 'Wiki'}, {'name': 'tickets', 'installable': True, 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'bugs', 'url': '/p/carracingprojec/bugs/', 'mount_label': 'Bugs'}, {'name': 'summary', 'installable': False, 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'url': '/p/carracingprojec/summary/', 'sourceforge_group_id': 266751, 'mount_label': 'Summary'}, {'name': 'reviews', 'installable': False, 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'url': '/p/carracingprojec/reviews/', 'mount_label': 'Reviews'}, {'name': 'support', 'installable': False, 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'url': '/p/carracingprojec/support/', 'mount_label': 'Support'}, {'name': 'files', 'installable': False, 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'url': '/p/carracingprojec/files/', 'mount_label': 'Files'}, {'name': 'activity', 'installable': False, 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'url': '/p/carracingprojec/activity/', 'mount_label': 'Activity'}, {'name': 'mailman', 'installable': False, 'tool_label': 'Mailing Lists', 'icons': {'48': ' ...
# ...
# {'name': 'cmph', 'avatar_url': None, 'path': 'cmph', 'ssh_url_to_repo': 'git@gitlab.com:mtrenkmann/cmph.git', 'id': 9184930, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fdf98c1500169e1dfde'), 'star_count': 0, 'name_with_namespace': 'Martin Trenkmann / cmph', 'description': 'C Minimal Perfect Hashing Library (imported from https://sourceforge.net/projects/cmph)', 'last_activity_at': '2018-11-02T18:23:12.234Z', 'created_at': '2018-11-02T15:38:46.046Z', 'http_url_to_repo': 'https://gitlab.com/mtrenkmann/cmph.git', 'path_with_namespace': 'mtrenkmann/cmph', 'default_branch': 'minimal', 'namespace': {'name': 'mtrenkmann', 'full_path': 'mtrenkmann', 'kind': 'user', 'path': 'mtrenkmann', 'parent_id': None, 'id': 1889700}, 'readme_url': 'https://gitlab.com/mtrenkmann/cmph/blob/minimal/README.md', 'web_url': 'https://gitlab.com/mtrenkmann/cmph'}
# {'name': 'CSE 4701 - Project 2 Part 1', 'avatar_url': None, 'path': 'cse-4701-proj2', 'ssh_url_to_repo': 'git@gitlab.com:Zyian/cse-4701-proj2.git', 'id': 9184654, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe498c1500169e1dfdf'), 'star_count': 0, 'name_with_namespace': 'Adrian Zygadlo / CSE 4701 - Project 2 Part 1', 'description': '', 'last_activity_at': '2018-11-02T15:17:39.304Z', 'created_at': '2018-11-02T15:17:39.304Z', 'http_url_to_repo': 'https://gitlab.com/Zyian/cse-4701-proj2.git', 'path_with_namespace': 'Zyian/cse-4701-proj2', 'default_branch': 'master', 'namespace': {'name': 'Zyian', 'full_path': 'Zyian', 'kind': 'user', 'path': 'Zyian', 'parent_id': None, 'id': 1524766}, 'readme_url': None, 'web_url': 'https://gitlab.com/Zyian/cse-4701-proj2'}
# {'name': 'CaesarTest', 'avatar_url': None, 'path': 'caesartest', 'ssh_url_to_repo': 'git@gitlab.com:Dp-149TAQC/caesartest.git', 'id': 9184523, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe498c1500169e1dfe0'), 'star_count': 0, 'name_with_namespace': 'Dp-149TAQC / CaesarTest', 'description': '', 'last_activity_at': '2018-11-02T17:41:00.582Z', 'created_at': '2018-11-02T15:07:22.425Z', 'http_url_to_repo': 'https://gitlab.com/Dp-149TAQC/caesartest.git', 'path_with_namespace': 'Dp-149TAQC/caesartest', 'default_branch': 'master', 'namespace': {'name': 'Dp-149TAQC', 'full_path': 'Dp-149TAQC', 'kind': 'group', 'path': 'Dp-149TAQC', 'parent_id': None, 'id': 3930159}, 'readme_url': None, 'web_url': 'https://gitlab.com/Dp-149TAQC/caesartest'}
# {'name': 'ckan-mirror', 'avatar_url': None, 'path': 'ckan-mirror', 'ssh_url_to_repo': 'git@gitlab.com:amiedes/ckan-mirror.git', 'id': 9184373, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe598c1500169e1dfe1'), 'star_count': 0, 'name_with_namespace': 'Alberto Miedes / ckan-mirror', 'description': '', 'last_activity_at': '2018-11-02T14:54:36.272Z', 'created_at': '2018-11-02T14:54:36.272Z', 'http_url_to_repo': 'https://gitlab.com/amiedes/ckan-mirror.git', 'path_with_namespace': 'amiedes/ckan-mirror', 'default_branch': 'master', 'namespace': {'name': 'amiedes', 'full_path': 'amiedes', 'kind': 'user', 'path': 'amiedes', 'parent_id': None, 'id': 2850279}, 'readme_url': 'https://gitlab.com/amiedes/ckan-mirror/blob/master/README.rst', 'web_url': 'https://gitlab.com/amiedes/ckan-mirror'}
# {'name': 'cookbook-guide-generator', 'avatar_url': None, 'path': 'cookbook-guide-generator', 'ssh_url_to_repo': 'git@gitlab.com:julienlevasseur/cookbook-guide-generator.git', 'id': 9184324, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe598c1500169e1dfe2'), 'star_count': 0, 'name_with_namespace': 'Julien Levasseur / cookbook-guide-generator', 'description': '', 'last_activity_at': '2018-11-02T14:51:06.580Z', 'created_at': '2018-11-02T14:51:06.580Z', 'http_url_to_repo': 'https://gitlab.com/julienlevasseur/cookbook-guide-generator.git', 'path_with_namespace': 'julienlevasseur/cookbook-guide-generator', 'default_branch': 'master', 'namespace': {'name': 'julienlevasseur', 'full_path': 'julienlevasseur', 'kind': 'user', 'path': 'julienlevasseur', 'parent_id': None, 'id': 2979492}, 'readme_url': 'https://gitlab.com/julienlevasseur/cookbook-guide-generator/blob/master/README.md', 'web_url': 'https://gitlab.com/julienlevasseur/cookbook-guide-generator'}
# {'name': 'conFusion', 'avatar_url': None, 'path': 'confusion', 'ssh_url_to_repo': 'git@gitlab.com:codeName_KC/confusion.git', 'id': 9184205, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe698c1500169e1dfe3'), 'star_count': 0, 'name_with_namespace': 'Kacey Okafor / conFusion', 'description': 'conFusion is an assignment by Wiredelta, which focuses on how to use Bootstrap for styling. ', 'last_activity_at': '2018-11-02T14:42:30.185Z', 'created_at': '2018-11-02T14:42:30.185Z', 'http_url_to_repo': 'https://gitlab.com/codeName_KC/confusion.git', 'path_with_namespace': 'codeName_KC/confusion', 'default_branch': 'master', 'namespace': {'name': 'codeName_KC', 'full_path': 'codeName_KC', 'kind': 'user', 'path': 'codeName_KC', 'parent_id': None, 'id': 3861762}, 'readme_url': None, 'web_url': 'https://gitlab.com/codeName_KC/confusion'}
# {'name': 'cartoon', 'avatar_url': None, 'path': 'cartoon', 'ssh_url_to_repo': 'git@gitlab.com:sharanp98/cartoon.git', 'id': 9184192, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe698c1500169e1dfe4'), 'star_count': 0, 'name_with_namespace': 'Sharan / cartoon', 'description': 'Tried to cartoonize live video using opencv,', 'last_activity_at': '2018-11-02T14:41:56.715Z', 'created_at': '2018-11-02T14:41:56.715Z', 'http_url_to_repo': 'https://gitlab.com/sharanp98/cartoon.git', 'path_with_namespace': 'sharanp98/cartoon', 'default_branch': 'master', 'namespace': {'name': 'sharanp98', 'full_path': 'sharanp98', 'kind': 'user', 'path': 'sharanp98', 'parent_id': None, 'id': 2607957}, 'readme_url': 'https://gitlab.com/sharanp98/cartoon/blob/master/README.md', 'web_url': 'https://gitlab.com/sharanp98/cartoon'}
# {'name': 'celcabs', 'avatar_url': None, 'path': 'celcabs', 'ssh_url_to_repo': 'git@gitlab.com:sharanp98/celcabs.git', 'id': 9184188, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe698c1500169e1dfe5'), 'star_count': 0, 'name_with_namespace': 'Sharan / celcabs', 'description': None, 'last_activity_at': '2018-11-02T14:41:55.973Z', 'created_at': '2018-11-02T14:41:55.973Z', 'http_url_to_repo': 'https://gitlab.com/sharanp98/celcabs.git', 'path_with_namespace': 'sharanp98/celcabs', 'default_branch': 'master', 'namespace': {'name': 'sharanp98', 'full_path': 'sharanp98', 'kind': 'user', 'path': 'sharanp98', 'parent_id': None, 'id': 2607957}, 'readme_url': 'https://gitlab.com/sharanp98/celcabs/blob/master/README.md', 'web_url': 'https://gitlab.com/sharanp98/celcabs'}
# {'name': 'cours uvt MP2L 2018_2019', 'avatar_url': None, 'path': 'cours-uvt-mp2l-2018_2019', 'ssh_url_to_repo': 'git@gitlab.com:oussama-ht/cours-uvt-mp2l-2018_2019.git', 'id': 9184029, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fe698c1500169e1dfe6'), 'star_count': 0, 'name_with_namespace': 'oussama / cours uvt MP2L 2018_2019', 'description': '', 'last_activity_at': '2018-11-02T14:30:29.802Z', 'created_at': '2018-11-02T14:30:29.802Z', 'http_url_to_repo': 'https://gitlab.com/oussama-ht/cours-uvt-mp2l-2018_2019.git', 'path_with_namespace': 'oussama-ht/cours-uvt-mp2l-2018_2019', 'default_branch': 'master', 'namespace': {'name': 'oussama-ht', 'full_path': 'oussama-ht', 'kind': 'user', 'path': 'oussama-ht', 'parent_id': None, 'id': 1802479}, 'readme_url': None, 'web_url': 'https://gitlab.com/oussama-ht/cours-uvt-mp2l-2018_2019'}
# {'name': 'CinemaApp', 'avatar_url': None, 'path': 'cinemaapp', 'ssh_url_to_repo': 'git@gitlab.com:silchencko/cinemaapp.git', 'id': 9183994, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9feb98c1500169e1dfe7'), 'star_count': 0, 'name_with_namespace': 'Kateryna / CinemaApp', 'description': 'Our first cinema project', 'last_activity_at': '2018-11-02T14:28:54.433Z', 'created_at': '2018-11-02T14:28:54.433Z', 'http_url_to_repo': 'https://gitlab.com/silchencko/cinemaapp.git', 'path_with_namespace': 'silchencko/cinemaapp', 'default_branch': 'master', 'namespace': {'name': 'silchencko', 'full_path': 'silchencko', 'kind': 'user', 'path': 'silchencko', 'parent_id': None, 'id': 3929827}, 'readme_url': 'https://gitlab.com/silchencko/cinemaapp/blob/master/README.md', 'web_url': 'https://gitlab.com/silchencko/cinemaapp'}
# {'name': 'Compilation_Principle', 'avatar_url': None, 'path': 'Compilation_Principle', 'ssh_url_to_repo': 'git@gitlab.com:pornbusiness/Compilation_Principle.git', 'id': 9183930, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fec98c1500169e1dfe8'), 'star_count': 0, 'name_with_namespace': 'pornbusinessman / Compilation_Principle', 'description': '编译原理课程相关程序', 'last_activity_at': '2018-11-02T14:23:15.975Z', 'created_at': '2018-11-02T14:23:15.975Z', 'http_url_to_repo': 'https://gitlab.com/pornbusiness/Compilation_Principle.git', 'path_with_namespace': 'pornbusiness/Compilation_Principle', 'default_branch': 'master', 'namespace': {'name': 'pornbusiness', 'full_path': 'pornbusiness', 'kind': 'user', 'path': 'pornbusiness', 'parent_id': None, 'id': 3670922}, 'readme_url': None, 'web_url': 'https://gitlab.com/pornbusiness/Compilation_Principle'}
# {'name': 'Campylobacter microsimulation', 'avatar_url': None, 'path': 'campylobacter-microsimulation', 'ssh_url_to_repo': 'git@gitlab.com:rasanderson/campylobacter-microsimulation.git', 'id': 9183697, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fec98c1500169e1dfe9'), 'star_count': 0, 'name_with_namespace': 'Roy Sanderson / Campylobacter microsimulation', 'description': '', 'last_activity_at': '2018-11-02T14:12:01.585Z', 'created_at': '2018-11-02T14:12:01.585Z', 'http_url_to_repo': 'https://gitlab.com/rasanderson/campylobacter-microsimulation.git', 'path_with_namespace': 'rasanderson/campylobacter-microsimulation', 'default_branch': 'master', 'namespace': {'name': 'rasanderson', 'full_path': 'rasanderson', 'kind': 'user', 'path': 'rasanderson', 'parent_id': None, 'id': 499737}, 'readme_url': 'https://gitlab.com/rasanderson/campylobacter-microsimulation/blob/master/README.md', 'web_url': 'https://gitlab.com/rasanderson/campylobacter-microsimulation'}
# {'name': 'Cau_truc_du_ lieu_va_giai_thuat_nang_cao', 'avatar_url': None, 'path': 'cau_truc_du_-lieu_va_giai_thuat_nang_cao', 'ssh_url_to_repo': 'git@gitlab.com:16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao.git', 'id': 9183585, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fec98c1500169e1dfea'), 'star_count': 0, 'name_with_namespace': 'THANH NGUYEN CHI / Cau_truc_du_ lieu_va_giai_thuat_nang_cao', 'description': '', 'last_activity_at': '2018-11-02T14:04:33.746Z', 'created_at': '2018-11-02T14:04:33.746Z', 'http_url_to_repo': 'https://gitlab.com/16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao.git', 'path_with_namespace': '16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao', 'default_branch': 'master', 'namespace': {'name': '16521118', 'full_path': '16521118', 'kind': 'user', 'path': '16521118', 'parent_id': None, 'id': 2651391}, 'readme_url': None, 'web_url': 'https://gitlab.com/16521118/cau_truc_du_-lieu_va_giai_thuat_nang_cao'}
# {'name': 'CinemaApp', 'avatar_url': None, 'path': 'cinemaapp', 'ssh_url_to_repo': 'git@gitlab.com:OlehRybalka/cinemaapp.git', 'id': 9183565, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 1, '_id': ObjectId('5bdc9fec98c1500169e1dfeb'), 'star_count': 0, 'name_with_namespace': 'OlehRybalka / CinemaApp', 'description': 'Our first cinema project', 'last_activity_at': '2018-11-02T14:02:26.648Z', 'created_at': '2018-11-02T14:02:26.648Z', 'http_url_to_repo': 'https://gitlab.com/OlehRybalka/cinemaapp.git', 'path_with_namespace': 'OlehRybalka/cinemaapp', 'default_branch': 'master', 'namespace': {'name': 'OlehRybalka', 'full_path': 'OlehRybalka', 'kind': 'user', 'path': 'OlehRybalka', 'parent_id': None, 'id': 3929712}, 'readme_url': 'https://gitlab.com/OlehRybalka/cinemaapp/blob/master/README.md', 'web_url': 'https://gitlab.com/OlehRybalka/cinemaapp'}
# {'name': 'conceptual-web-extension', 'avatar_url': None, 'path': 'conceptual-web-extension', 'ssh_url_to_repo': 'git@gitlab.com:Conceptual-Learning/conceptual-web-extension.git', 'id': 9183526, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fed98c1500169e1dfec'), 'star_count': 0, 'name_with_namespace': 'Conceptual / conceptual-web-extension', 'description': '', 'last_activity_at': '2018-11-02T13:59:33.535Z', 'created_at': '2018-11-02T13:59:33.535Z', 'http_url_to_repo': 'https://gitlab.com/Conceptual-Learning/conceptual-web-extension.git', 'path_with_namespace': 'Conceptual-Learning/conceptual-web-extension', 'default_branch': 'master', 'namespace': {'name': 'Conceptual', 'full_path': 'Conceptual-Learning', 'kind': 'group', 'path': 'Conceptual-Learning', 'parent_id': None, 'id': 3612867}, 'readme_url': 'https://gitlab.com/Conceptual-Learning/conceptual-web-extension/blob/master/README.md', 'web_url': 'https://gitlab.com/Conceptual-Learning/conceptual-web-extension'}
# {'name': 'ClimbingStairs', 'avatar_url': None, 'path': 'climbingstairs', 'ssh_url_to_repo': 'git@gitlab.com:a.g-h/climbingstairs.git', 'id': 9183409, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fed98c1500169e1dfed'), 'star_count': 0, 'name_with_namespace': 'Akihiro Gaevsky-Hanada / ClimbingStairs', 'description': '', 'last_activity_at': '2018-11-02T13:51:38.195Z', 'created_at': '2018-11-02T13:51:38.195Z', 'http_url_to_repo': 'https://gitlab.com/a.g-h/climbingstairs.git', 'path_with_namespace': 'a.g-h/climbingstairs', 'default_branch': 'master', 'namespace': {'name': 'a.g-h', 'full_path': 'a.g-h', 'kind': 'user', 'path': 'a.g-h', 'parent_id': None, 'id': 2014859}, 'readme_url': None, 'web_url': 'https://gitlab.com/a.g-h/climbingstairs'}
# {'name': 'cj1', 'avatar_url': None, 'path': 'cj1', 'ssh_url_to_repo': 'git@gitlab.com:gzson79/cj1.git', 'id': 9183260, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fed98c1500169e1dfee'), 'star_count': 0, 'name_with_namespace': 'Sean / cj1', 'description': 'Dev Technology Codejam 1', 'last_activity_at': '2018-11-02T15:01:06.259Z', 'created_at': '2018-11-02T13:38:35.676Z', 'http_url_to_repo': 'https://gitlab.com/gzson79/cj1.git', 'path_with_namespace': 'gzson79/cj1', 'default_branch': None, 'namespace': {'name': 'gzson79', 'full_path': 'gzson79', 'kind': 'user', 'path': 'gzson79', 'parent_id': None, 'id': 2175736}, 'readme_url': None, 'web_url': 'https://gitlab.com/gzson79/cj1'}
# {'name': 'CarbonFootprint-Mobile', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/9183072/globe-256.png', 'path': 'CarbonFootprint-Mobile', 'ssh_url_to_repo': 'git@gitlab.com:sagar-kalra/CarbonFootprint-Mobile.git', 'id': 9183072, 'tag_list': [], 'forge': 'gitlab', 'forks_count': 0, '_id': ObjectId('5bdc9fee98c1500169e1dfef'), 'star_count': 0, 'name_with_namespace': 'Sagar Kalra / CarbonFootprint-Mobile', 'description': "A hybrid mobile application developed using React Native to calculate amount of emitted co2 based on user's activity", 'last_activity_at': '2018-11-02T13:24:49.973Z', 'created_at': '2018-11-02T13:24:49.973Z', 'http_url_to_repo': 'https://gitlab.com/sagar-kalra/CarbonFootprint-Mobile.git', 'path_with_namespace': 'sagar-kalra/CarbonFootprint-Mobile', 'default_branch': 'master', 'namespace': {'name': 'sagar-kalra', 'full_path': 'sagar-kalra', 'kind': 'user', 'path': 'sagar-kalra', 'parent_id': None, 'id': 3249692}, 'readme_url': 'https://gitlab.com/sagar-kalra/CarbonFootprint-Mobile/blob/master/README.md', 'web_url': 'https://gitlab.com/sagar-kalra/CarbonFootprint-Mobile'}

# %%
dbname = "fdac18mp2" #please use this database
collname = "sf_pgoedec1" #please modify so you store data in your collection
my_char = 'c'

# beginning page index
begin = "1"




for r in coll.find():
    print(r)
# Out:
# {'name': ' Car Racing Project 2010 ', 'labels': [], 'url': 'https://sourceforge.net/p/carracingprojec/', 'preferred_support_tool': '', 'screenshots': [{'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220836.jpg', 'caption': 'FinishLine on track 1', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220836.jpg/thumb'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220842.jpg', 'caption': 'Second Track Begining', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220842.jpg/thumb'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220834.jpg', 'caption': 'Begining of race on Track 1', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220834.jpg/thumb'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220832.jpg', 'caption': 'The Screen where you select a Track', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220832.jpg/thumb'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220846.jpg', 'caption': 'Startup Screen', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220846.jpg/thumb'}, {'url': 'https://sourceforge.net/p/carracingprojec/screenshot/220848.jpg', 'caption': 'Select car', 'thumbnail_url': 'https://sourceforge.net/p/carracingprojec/screenshot/220848.jpg/thumb'}], 'forge': 'sourceforge', '_id': '515b2b0234309d2f211834ee', 'creation_date': '2009-06-23', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'This project involves car race where one has to get to the finishing point before the given time elapses. The project is an open source and any is allow to develop on it.', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 6 - Mature', 'fullname': '6 - Mature', 'shortname': 'mature', 'id': 12}, {'fullpath': 'Development Status :: 5 - Production/Stable', 'fullname': '5 - Production/Stable', 'shortname': 'production', 'id': 11}, {'fullpath': 'Development Status :: 4 - Beta', 'fullname': '4 - Beta', 'shortname': 'beta', 'id': 10}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Graphical :: Win32 (MS Windows)', 'fullname': 'Win32 (MS Windows)', 'shortname': 'win32', 'id': 230}], 'language': [{'fullpath': 'Programming Language :: C++', 'fullname': 'C++', 'shortname': 'cpp', 'id': 165}], 'audience': [{'fullpath': 'Intended Audience :: by Industry or Sector :: Legal Industry', 'fullname': 'Legal Industry', 'shortname': 'legalindustry', 'id': 364}, {'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [{'fullpath': 'Topic :: Games/Entertainment :: Hobbies', 'fullname': 'Hobbies', 'shortname': 'hobbies', 'id': 772}, {'fullpath': 'Topic :: Games/Entertainment :: Game development framework', 'fullname': 'Game development framework', 'shortname': 'gameframeworks', 'id': 794}, {'fullpath': 'Topic :: Games/Entertainment :: Sports', 'fullname': 'Sports', 'shortname': 'sports', 'id': 806}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: Open Software License', 'fullname': 'Open Software License', 'shortname': 'osl', 'id': 388}, {'fullpath': 'License :: OSI-Approved Open Source :: Academic Free License (AFL)', 'fullname': 'Academic Free License (AFL)', 'shortname': 'afl', 'id': 324}], 'os': [{'fullpath': 'Operating System :: Modern (Vendor-Supported) Desktop Operating Systems :: WinXP', 'fullname': 'WinXP', 'shortname': 'mswin_xp', 'id': 419}, {'fullpath': 'Operating System :: Modern (Vendor-Supported) Desktop Operating Systems :: Vista', 'fullname': 'Vista', 'shortname': 'vista', 'id': 657}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'https://carracingprojec.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Calvin Marqques Omondi', 'url': 'https: ...
# {'name': ' c-cgi-lib', 'labels': [], 'url': 'https://sourceforge.net/p/ccgilib/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '5009df24b9363c62aa0000d6', 'creation_date': '2012-07-20', 'socialnetworks': [], 'icon_url': None, 'summary': 'This library allow you to simply create CGI for a light-loaded server.', 'short_description': 'This library allow you to simply create CGI for a light-loaded server. It consists a functions for working with authentication/authorisation, XML-http-requests, cookies, sqlite databases. ', 'categories': {'developmentstatus': [], 'database': [], 'environment': [], 'language': [], 'audience': [], 'topic': [], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 3.0 (GPLv3)', 'fullname': 'GNU General Public License version 3.0 (GPLv3)', 'shortname': 'gplv3', 'id': 679}], 'os': [], 'translation': []}, 'external_homepage': '', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Edward', 'url': 'https://sourceforge.net/u/eddyem/', 'username': 'eddyem'}], 'tools': [{'name': 'hg', 'url': '/p/ccgilib/code/', 'tool_label': 'Mercurial', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': True, 'mount_label': 'Code'}, {'name': 'tickets', 'url': '/p/ccgilib/tickets/', 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'tickets', 'installable': True, 'mount_label': 'Tickets'}, {'name': 'wiki', 'url': '/p/ccgilib/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'discussion', 'url': '/p/ccgilib/discussion/', 'tool_label': 'Discussion', 'icons': {'48': 'images/forums_48.png', '24': 'images/forums_24.png', '32': 'images/forums_32.png'}, 'mount_point': 'discussion', 'installable': True, 'mount_label': 'Discussion'}, {'name': 'files', 'url': '/p/ccgilib/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'support', 'url': '/p/ccgilib/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'reviews', 'url': '/p/ccgilib/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'summary', 'url': '/p/ccgilib/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 830285, 'mount_label': 'Summary'}, {'name': 'activity', 'url': '/p/ccgilib/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}], 'moved_to_url': '', 'shortname': 'ccgilib', 'status': 'active'}
# {'name': '#C++', 'labels': [], 'url': 'https://sourceforge.net/p/cpp/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '513e2d1234309d5445076ee6', 'creation_date': '2003-07-08', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'QuakeNet #C++', 'categories': {'developmentstatus': [], 'database': [], 'environment': [], 'language': [{'fullpath': 'Programming Language :: C++', 'fullname': 'C++', 'shortname': 'cpp', 'id': 165}, {'fullpath': 'Programming Language :: C', 'fullname': 'C', 'shortname': 'c', 'id': 164}], 'audience': [], 'topic': [], 'license': [], 'os': [], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'http://cpp.sourceforge.net', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Jukka Helle', 'url': 'https://sourceforge.net/u/squider/', 'username': 'squider'}, {'name': 'Wilhelm Svenselius', 'url': 'https://sourceforge.net/u/w2k/', 'username': 'w2k'}, {'name': 'Johan Larsson', 'url': 'https://sourceforge.net/u/targhan/', 'username': 'targhan'}], 'tools': [{'name': 'blog', 'url': '/p/cpp/news/', 'tool_label': 'Blog', 'icons': {'48': 'images/blog_48.png', '24': 'images/blog_24.png', '32': 'images/blog_32.png'}, 'mount_point': 'news', 'installable': True, 'mount_label': 'News'}, {'name': 'reviews', 'url': '/p/cpp/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'support', 'url': '/p/cpp/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'tickets', 'url': '/p/cpp/feature-requests/', 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'feature-requests', 'installable': True, 'mount_label': 'Feature Requests'}, {'name': 'wiki', 'url': '/p/cpp/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/cpp/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'summary', 'url': '/p/cpp/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 85217, 'mount_label': 'Summary'}, {'name': 'activity', 'url': '/p/cpp/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}], 'moved_to_url': '', 'shortname': 'cpp', 'status': 'active'}
# {'name': '(Cool OS) Enviro', 'labels': [], 'url': 'https://sourceforge.net/p/coolos/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '51268dfd5fcbc97fa5baa2e6', 'creation_date': '2001-05-13', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'Quake II-based 3D shell, currently aimed for Windows (Linux in consideration). The project hopes to create a much more logical user experience for performing common tasks inside a computer, while establishing a three-dimensional online world.', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 7 - Inactive', 'fullname': '7 - Inactive', 'shortname': 'inactive', 'id': 358}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Graphical :: Win32 (MS Windows)', 'fullname': 'Win32 (MS Windows)', 'shortname': 'win32', 'id': 230}], 'language': [{'fullpath': 'Programming Language :: C++', 'fullname': 'C++', 'shortname': 'cpp', 'id': 165}, {'fullpath': 'Programming Language :: C', 'fullname': 'C', 'shortname': 'c', 'id': 164}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: System Administrators', 'fullname': 'System Administrators', 'shortname': 'sysadmins', 'id': 4}, {'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}, {'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers', 'id': 2}], 'topic': [{'fullpath': 'Topic :: System :: System Shells', 'fullname': 'System Shells', 'shortname': 'shells', 'id': 294}, {'fullpath': 'Topic :: Multimedia :: Graphics', 'fullname': 'Graphics', 'shortname': 'graphics', 'id': 100}, {'fullpath': 'Topic :: Multimedia :: Sound/Audio', 'fullname': 'Sound/Audio', 'shortname': 'sound', 'id': 113}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)', 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'id': 15}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: 32-bit MS Windows (95/98)', 'fullname': '32-bit MS Windows (95/98)', 'shortname': 'win95', 'id': 218}, {'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'http://coolos.sourceforge.net', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Kreg Mosier', 'url': 'https://sourceforge.net/u/kreg/', 'username': 'kreg'}, {'name': 'Guy Paddock', 'url': 'https://sourceforge.net/u/guypaddock/', 'username': 'guypaddock'}, {'name': 'Karl Cartwright', 'url': 'https://sourceforge.net/u/kazbear/', 'username': 'kazbear'}], 'tools': [{'name': 'mailman', 'url': '/p/coolos/mailman/', 'tool_label': 'Mailing Lists', 'icons': {'48': 'images/forums_48.png', '24': 'images/forums_24.png', '32': 'images/forums_32.png'}, 'mount_point': 'mailman', 'installable': False, 'mount_label': 'Mailing Lists'}, {'name': 'blog', 'url': '/p/coolos/news/', 'tool_label': 'Blog', 'icons': {'48': 'images/blog_48.png', '24': 'images/blog_24.png', '32': 'images/blog_32.png'}, 'mount_point': 'news', 'installable': True, 'mount_label': 'News'}, {'name': 'cvs', 'url': '/p/coolos/code/', 'tool_label': 'CVS', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': False, 'mount_label': 'Code'}, {'name': 'wiki', 'url': '/p/coolos/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/coolos/files/', 'too ...
# {'name': '-', 'labels': [], 'url': 'https://sourceforge.net/p/cachesubmitter/', 'preferred_support_tool': '_url', 'screenshots': [], 'forge': 'sourceforge', '_id': '515b299b27184602d9f0ce64', 'creation_date': '2010-05-03', 'socialnetworks': [], 'icon_url': 'https://sourceforge.net/p/cachesubmitter/icon', 'summary': '', 'short_description': '-', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 4 - Beta', 'fullname': '4 - Beta', 'shortname': 'beta', 'id': 10}], 'database': [{'fullpath': 'Database Environment :: Database API :: XML-based', 'fullname': 'XML-based', 'shortname': 'db_api_xml', 'id': 507}], 'environment': [{'fullpath': 'User Interface :: Graphical :: Win32 (MS Windows)', 'fullname': 'Win32 (MS Windows)', 'shortname': 'win32', 'id': 230}], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers', 'id': 2}], 'topic': [], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 3.0 (GPLv3)', 'fullname': 'GNU General Public License version 3.0 (GPLv3)', 'shortname': 'gplv3', 'id': 679}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: 32-bit MS Windows (NT/2000/XP)', 'fullname': '32-bit MS Windows (NT/2000/XP)', 'shortname': 'winnt', 'id': 219}], 'translation': [{'fullpath': 'Translations :: Dutch', 'fullname': 'Dutch', 'shortname': 'dutch', 'id': 330}, {'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'http://www.globalcaching.nl/tools/', 'private': False, 'video_url': '', 'preferred_support_url': 'http://sourceforge.net/projects/cachesubmitter/forums/forum/1138488', 'developers': [{'name': 'Robert Peters', 'url': 'https://sourceforge.net/u/hemenrob/', 'username': 'hemenrob'}], 'tools': [{'name': 'summary', 'url': '/p/cachesubmitter/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 320393, 'mount_label': 'Summary'}, {'name': 'wiki', 'url': '/p/cachesubmitter/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/cachesubmitter/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'support', 'url': '/p/cachesubmitter/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'reviews', 'url': '/p/cachesubmitter/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'activity', 'url': '/p/cachesubmitter/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}], 'moved_to_url': '', 'shortname': 'cachesubmitter', 'status': 'active'}
# {'name': '--', 'labels': [], 'url': 'https://sourceforge.net/p/calcoboter/', 'preferred_support_tool': 'wiki', 'screenshots': [], 'forge': 'sourceforge', '_id': '4fc086aeb9363c56ac0000e6', 'creation_date': '2012-05-26', 'socialnetworks': [{'socialnetwork': 'Twitter', 'accounturl': ''}, {'socialnetwork': 'Facebook', 'accounturl': None}], 'icon_url': None, 'summary': '', 'short_description': '', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 3 - Alpha', 'fullname': '3 - Alpha', 'shortname': 'alpha', 'id': 9}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Toolkits/Libraries :: Qt', 'fullname': 'Qt', 'shortname': 'ui_qt', 'id': 479}], 'language': [{'fullpath': 'Programming Language :: C++', 'fullname': 'C++', 'shortname': 'cpp', 'id': 165}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Advanced End Users', 'fullname': 'Advanced End Users', 'shortname': 'enduser_advanced', 'id': 536}, {'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers', 'id': 2}, {'fullpath': 'Intended Audience :: Other Audience', 'fullname': 'Other Audience', 'shortname': 'other', 'id': 5}], 'topic': [{'fullpath': 'Topic :: Scientific/Engineering :: Mathematics', 'fullname': 'Mathematics', 'shortname': 'mathematics', 'id': 98}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: BSD License', 'fullname': 'BSD License', 'shortname': 'bsd', 'id': 187}], 'os': [{'fullpath': 'Operating System :: Emulation and API Compatibility :: MinGW/MSYS (MS Windows)', 'fullname': 'MinGW/MSYS (MS Windows)', 'shortname': 'mingw_msys', 'id': 445}, {'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}, {'fullpath': 'Operating System :: Grouping and Descriptive Categories :: 64-bit MS Windows', 'fullname': '64-bit MS Windows', 'shortname': 'win64', 'id': 655}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': None, 'private': False, 'video_url': None, 'preferred_support_url': '', 'developers': [], 'tools': [{'name': 'discussion', 'url': '/p/calcoboter/discussion/', 'tool_label': 'Discussion', 'icons': {'48': 'images/forums_48.png', '24': 'images/forums_24.png', '32': 'images/forums_32.png'}, 'mount_point': 'discussion', 'installable': True, 'mount_label': 'Discussion'}, {'name': 'tickets', 'url': '/p/calcoboter/tickets/', 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'tickets', 'installable': True, 'mount_label': 'Tickets'}, {'name': 'wiki', 'url': '/p/calcoboter/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/calcoboter/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'support', 'url': '/p/calcoboter/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'summary', 'url': '/p/calcoboter/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 779711, 'mount_label': 'Summary'}, {'name': 'reviews', 'url': '/p/calcoboter/reviews/', 'tool_label': 'Reviews', 'icons' ...
# {'name': '.NET Calendar Control', 'labels': [], 'url': 'https://sourceforge.net/p/calendarviewer/', 'preferred_support_tool': '', 'screenshots': [{'url': 'https://sourceforge.net/p/calendarviewer/screenshot/186611.jpg', 'caption': 'This is the main window using the calender viewer control.', 'thumbnail_url': 'https://sourceforge.net/p/calendarviewer/screenshot/186611.jpg/thumb'}], 'forge': 'sourceforge', '_id': '515b29505fcbc9797bdcba67', 'creation_date': '2007-10-12', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'This is a calendar control with multi-select. It provides a point and click interface for selecting holidays or special days. It previously extended on MonthCalendar, now it has a fixed size in all regions and all drawing is handled internally.', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 5 - Production/Stable', 'fullname': '5 - Production/Stable', 'shortname': 'production', 'id': 11}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Graphical :: .NET/Mono', 'fullname': '.NET/Mono', 'shortname': 'ui_dotnet', 'id': 469}], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [{'fullpath': 'Topic :: Software Development :: Object Oriented', 'fullname': 'Object Oriented', 'shortname': 'swdev_oo', 'id': 562}, {'fullpath': 'Topic :: Software Development :: User Interfaces', 'fullname': 'User Interfaces', 'shortname': 'softwaredev_ui', 'id': 561}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU Library or Lesser General Public License version 2.0 (LGPLv2)', 'fullname': 'GNU Library or Lesser General Public License version 2.0 (LGPLv2)', 'shortname': 'lgpl', 'id': 16}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: OS Independent (Written in an interpreted language)', 'fullname': 'OS Independent (Written in an interpreted language)', 'shortname': 'independent', 'id': 235}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}, {'fullpath': 'Translations :: Swedish', 'fullname': 'Swedish', 'shortname': 'swedish', 'id': 348}]}, 'external_homepage': 'https://calendarviewer.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Kasreyn', 'url': 'https://sourceforge.net/u/kasreyn/', 'username': 'kasreyn'}], 'tools': [{'name': 'summary', 'url': '/p/calendarviewer/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 207753, 'mount_label': 'Summary'}, {'name': 'reviews', 'url': '/p/calendarviewer/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'wiki', 'url': '/p/calendarviewer/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'tickets', 'url': '/p/calendarviewer/bugs/', 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'bugs', 'installable': True, 'mount_label': 'Bugs'}, {'name': 'support', 'url': '/p/calendarviewer/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'S ...
# {'name': '.NET Class Lookup Deskbar Extension', 'labels': [], 'url': 'https://sourceforge.net/p/classlookupgde/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '513a0b2a271846033bf55b06', 'creation_date': '2005-03-07', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'The .NET Class Lookup extension for Google Deskbar is a C# library that provides a custom query for displaying .NET Framework 1.1 documentation', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 4 - Beta', 'fullname': '4 - Beta', 'shortname': 'beta', 'id': 10}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Plugins', 'fullname': 'Plugins', 'shortname': 'ui_plugins', 'id': 461}], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: Open Software License', 'fullname': 'Open Software License', 'shortname': 'osl', 'id': 388}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}], 'translation': []}, 'external_homepage': 'http://classlookupgde.sourceforge.net', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Adam Crossland', 'url': 'https://sourceforge.net/u/adamcrossland/', 'username': 'adamcrossland'}], 'tools': [{'name': 'files', 'url': '/p/classlookupgde/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'support', 'url': '/p/classlookupgde/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'cvs', 'url': '/p/classlookupgde/code/', 'tool_label': 'CVS', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': False, 'mount_label': 'Code'}, {'name': 'summary', 'url': '/p/classlookupgde/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 133302, 'mount_label': 'Summary'}, {'name': 'wiki', 'url': '/p/classlookupgde/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'reviews', 'url': '/p/classlookupgde/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'activity', 'url': '/p/classlookupgde/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}], 'moved_to_url': '', 'shortname': 'classlookupgde', 'status': 'active'}
# {'name': '.NET Collection Code Generator', 'labels': [], 'url': 'https://sourceforge.net/p/colcodegen/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '513e2cb334309d5f016db934', 'creation_date': '2003-09-03', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'A generator for strongly typed .NET collections.  Templates will define exactly how the code appears for each language and for each type of collection.', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 5 - Production/Stable', 'fullname': '5 - Production/Stable', 'shortname': 'production', 'id': 11}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Graphical :: Win32 (MS Windows)', 'fullname': 'Win32 (MS Windows)', 'shortname': 'win32', 'id': 230}], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [{'fullpath': 'Topic :: Software Development :: Code Generators', 'fullname': 'Code Generators', 'shortname': 'codegen', 'id': 259}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)', 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'id': 15}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'https://colcodegen.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Michael', 'url': 'https://sourceforge.net/u/versat1474/', 'username': 'versat1474'}], 'tools': [{'name': 'summary', 'url': '/p/colcodegen/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 89362, 'mount_label': 'Summary'}, {'name': 'support', 'url': '/p/colcodegen/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'reviews', 'url': '/p/colcodegen/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'wiki', 'url': '/p/colcodegen/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'blog', 'url': '/p/colcodegen/news/', 'tool_label': 'Blog', 'icons': {'48': 'images/blog_48.png', '24': 'images/blog_24.png', '32': 'images/blog_32.png'}, 'mount_point': 'news', 'installable': True, 'mount_label': 'News'}, {'name': 'files', 'url': '/p/colcodegen/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'link', 'url': '/p/colcodegen/donate/', 'tool_label': 'External Link', 'icons': {'48': 'images/ext_48.png', '24': 'images/ext_24.png', '32': 'images/ext_32.png'}, 'mount_point': 'donate', 'installable': True, 'mount_label': 'Donate'}, {'name': 'activity', 'url': '/p/colcodegen/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/adm ...
# {'name': '.NET wrapper for the Centera SDK', 'labels': [], 'url': 'https://sourceforge.net/p/cosi-dot-net/', 'preferred_support_tool': '_url', 'screenshots': [], 'forge': 'sourceforge', '_id': '5170311b2718467af2af075c', 'creation_date': '2006-03-06', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'The .Net wrapper for the Centera SDK is an open source project that is part of the EMC Centera Open Source Initiative (COSI). The EMC Centera Open Source Initiative is for toolkits and applications that interact with the EMC Centera content addressed sto', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 6 - Mature', 'fullname': '6 - Mature', 'shortname': 'mature', 'id': 12}], 'database': [], 'environment': [], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by Industry or Sector :: Science/Research', 'fullname': 'Science/Research', 'shortname': 'scienceresearch', 'id': 367}, {'fullpath': 'Intended Audience :: by End-User Class :: System Administrators', 'fullname': 'System Administrators', 'shortname': 'sysadmins', 'id': 4}, {'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [{'fullpath': 'Topic :: Software Development', 'fullname': 'Software Development', 'shortname': 'development', 'id': 45}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)', 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'id': 15}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}], 'translation': []}, 'external_homepage': 'https://community.emc.com/community/edn/centera/centerasdk?view=discussions', 'private': False, 'video_url': '', 'preferred_support_url': 'http://sourceforge.net/project/memberlist.php?group_id=161759', 'developers': [{'name': 'Paul McKeown', 'url': 'https://sourceforge.net/u/userid-1888983/', 'username': 'mckeown_paul'}, {'name': 'Graham Stuart (EMC)', 'url': 'https://sourceforge.net/u/gstuart/', 'username': 'gstuart'}], 'tools': [{'name': 'support', 'url': '/p/cosi-dot-net/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'reviews', 'url': '/p/cosi-dot-net/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'wiki', 'url': '/p/cosi-dot-net/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'tickets', 'url': '/p/cosi-dot-net/patches/', 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'patches', 'installable': True, 'mount_label': 'Patches'}, {'name': 'files', 'url': '/p/cosi-dot-net/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'summary', 'url': '/p/cosi-dot-net/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 161759, ...
# {'name': '.Net Object Cache System', 'labels': [], 'url': 'https://sourceforge.net/p/cache-net/', 'preferred_support_tool': '_url', 'screenshots': [], 'forge': 'sourceforge', '_id': '513e2b3c2718460365093d80', 'creation_date': '2004-03-19', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'a .net object cache system like those of java. help store all kinds of information here.', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 2 - Pre-Alpha', 'fullname': '2 - Pre-Alpha', 'shortname': 'prealpha', 'id': 8}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Graphical :: Win32 (MS Windows)', 'fullname': 'Win32 (MS Windows)', 'shortname': 'win32', 'id': 230}], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)', 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'id': 15}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}], 'translation': [{'fullpath': 'Translations :: Chinese (Simplified)', 'fullname': 'Chinese (Simplified)', 'shortname': 'chinesesimplified', 'id': 382}]}, 'external_homepage': 'https://cache-net.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': 'http://sourceforge.net/tracker/?func=add&group_id=104933&atid=639743', 'developers': [{'name': 'jin shi', 'url': 'https://sourceforge.net/u/userid-1001623/', 'username': 'killy_shell'}], 'tools': [{'name': 'support', 'url': '/p/cache-net/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'reviews', 'url': '/p/cache-net/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'wiki', 'url': '/p/cache-net/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/cache-net/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'link', 'url': '/p/cache-net/donate/', 'tool_label': 'External Link', 'icons': {'48': 'images/ext_48.png', '24': 'images/ext_24.png', '32': 'images/ext_32.png'}, 'mount_point': 'donate', 'installable': True, 'mount_label': 'Donate'}, {'name': 'summary', 'url': '/p/cache-net/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 104933, 'mount_label': 'Summary'}, {'name': 'activity', 'url': '/p/cache-net/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}, {'name': 'mailman', 'url': '/p/cache-net/mailman/', 'tool_label': 'Mailing Lists', 'icons': {'48': 'images/forums_48.png', '24': 'images/forums_24.png', '32': 'images/forums_32.png'}, 'mount_point': 'mailman', 'installable': F ...
# {'name': '.net-commons-config', 'labels': [''], 'url': 'https://sourceforge.net/p/commonsconfig/', 'preferred_support_tool': 'tickets', 'screenshots': [], 'forge': 'sourceforge', '_id': '524691400910d45b0f91dfd3', 'creation_date': '2013-09-28', 'socialnetworks': [{'socialnetwork': 'Twitter', 'accounturl': ''}], 'icon_url': None, 'summary': 'Porting of the Apache commons-configuration library to .net', 'short_description': '', 'categories': {'developmentstatus': [], 'database': [], 'environment': [], 'language': [{'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp', 'id': 271}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [{'fullpath': 'Topic :: Software Development :: Libraries', 'fullname': 'Libraries', 'shortname': 'softdevlibraries', 'id': 770}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 3.0 (GPLv3)', 'fullname': 'GNU General Public License version 3.0 (GPLv3)', 'shortname': 'gplv3', 'id': 679}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit', 'id': 435}], 'translation': []}, 'external_homepage': None, 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Joao Correlo', 'url': 'https://sourceforge.net/u/jcorrelo/', 'username': 'jcorrelo'}], 'tools': [{'name': 'support', 'url': '/p/commonsconfig/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'summary', 'url': '/p/commonsconfig/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 1965584, 'mount_label': 'Summary'}, {'name': 'reviews', 'url': '/p/commonsconfig/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'tickets', 'url': '/p/commonsconfig/tickets/', 'tool_label': 'Tickets', 'icons': {'48': 'images/tickets_48.png', '24': 'images/tickets_24.png', '32': 'images/tickets_32.png'}, 'mount_point': 'tickets', 'installable': True, 'mount_label': 'Tickets'}, {'name': 'discussion', 'url': '/p/commonsconfig/discussion/', 'tool_label': 'Discussion', 'icons': {'48': 'images/forums_48.png', '24': 'images/forums_24.png', '32': 'images/forums_32.png'}, 'mount_point': 'discussion', 'installable': True, 'mount_label': 'Discussion'}, {'name': 'files', 'url': '/p/commonsconfig/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'svn', 'url': '/p/commonsconfig/code/', 'tool_label': 'SVN', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': True, 'mount_label': 'Code'}, {'name': 'activity', 'url': '/p/commonsconfig/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}], 'moved_to_url': '', 'shortname': 'commonsconfig', 'status': 'active'}
# ...
# {'name': 'A CGI Library for C', 'labels': [], 'url': 'https://sourceforge.net/p/cgi-c/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '517021a0e88f3d0ab9dbf561', 'creation_date': '2007-09-19', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'This is an extremely memory and speed optimized CGI library written in ANSI C. It does all the normal CGI functions and also can receive file uploads. It can be used with FastCGI.', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 5 - Production/Stable', 'fullname': '5 - Production/Stable', 'shortname': 'production', 'id': 11}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Web-based', 'fullname': 'Web-based', 'shortname': 'web', 'id': 237}], 'language': [{'fullpath': 'Programming Language :: C', 'fullname': 'C', 'shortname': 'c', 'id': 164}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}], 'topic': [{'fullpath': 'Topic :: Internet :: WWW/HTTP :: Dynamic Content :: CGI Tools/Libraries', 'fullname': 'CGI Tools/Libraries', 'shortname': 'cgi', 'id': 96}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU Library or Lesser General Public License version 2.0 (LGPLv2)', 'fullname': 'GNU Library or Lesser General Public License version 2.0 (LGPLv2)', 'shortname': 'lgpl', 'id': 16}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: OS Portable (Source code to work with many OS platforms)', 'fullname': 'OS Portable (Source code to work with many OS platforms)', 'shortname': 'os_portable', 'id': 436}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'https://cgi-c.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Hagen Patzke', 'url': 'https://sourceforge.net/u/hpat/', 'username': 'hpat'}, {'name': 'Bill Chatfield', 'url': 'https://sourceforge.net/u/bchat/', 'username': 'bchat'}], 'tools': [{'name': 'link', 'url': '/p/cgi-c/donate/', 'tool_label': 'External Link', 'icons': {'48': 'images/ext_48.png', '24': 'images/ext_24.png', '32': 'images/ext_32.png'}, 'mount_point': 'donate', 'installable': True, 'mount_label': 'Donate'}, {'name': 'svn', 'url': '/p/cgi-c/code/', 'tool_label': 'SVN', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': True, 'mount_label': 'Code'}, {'name': 'summary', 'url': '/p/cgi-c/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 206046, 'mount_label': 'Summary'}, {'name': 'wiki', 'url': '/p/cgi-c/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/cgi-c/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'reviews', 'url': '/p/cgi-c/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'support', 'url': '/p/cgi-c/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'activity', 'url': ...
# {'name': 'A Cocoa GUI for GNU Backgammon', 'labels': [], 'url': 'https://sourceforge.net/p/cocoagammon/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '517029cf5fcbc979b9e0793f', 'creation_date': '2006-07-21', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'A Cocoa based GUI wrapping command-line GNU Backgammon', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 1 - Planning', 'fullname': '1 - Planning', 'shortname': 'planning', 'id': 7}], 'database': [], 'environment': [{'fullpath': 'User Interface :: Graphical :: Cocoa (MacOS X)', 'fullname': 'Cocoa (MacOS X)', 'shortname': 'cocoa', 'id': 310}, {'fullpath': 'User Interface :: Toolkits/Libraries :: Quartz', 'fullname': 'Quartz', 'shortname': 'ui_quartz', 'id': 494}], 'language': [{'fullpath': 'Programming Language :: Objective C', 'fullname': 'Objective C', 'shortname': 'objectivec', 'id': 174}], 'audience': [{'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers', 'id': 2}], 'topic': [{'fullpath': 'Topic :: Games/Entertainment :: Board Games', 'fullname': 'Board Games', 'shortname': 'boardgames', 'id': 287}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)', 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'id': 15}], 'os': [{'fullpath': 'Operating System :: Modern (Vendor-Supported) Desktop Operating Systems :: OS X', 'fullname': 'OS X', 'shortname': 'macosx', 'id': 309}], 'translation': [{'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english', 'id': 275}]}, 'external_homepage': 'https://cocoagammon.sourceforge.io', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'Gabriel de Dietrich', 'url': 'https://sourceforge.net/u/drgvond/', 'username': 'drgvond'}], 'tools': [{'name': 'summary', 'url': '/p/cocoagammon/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 172894, 'mount_label': 'Summary'}, {'name': 'files', 'url': '/p/cocoagammon/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'support', 'url': '/p/cocoagammon/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'wiki', 'url': '/p/cocoagammon/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'reviews', 'url': '/p/cocoagammon/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'svn', 'url': '/p/cocoagammon/code/', 'tool_label': 'SVN', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': True, 'mount_label': 'Code'}, {'name': 'activity', 'url': '/p/cocoagammon/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount_label': 'Activity'}, {'name': 'mailman', 'url': '/p/cocoagammon/mailman/', 'tool_label': 'Mailing Lists', 'icons': {'48': 'images/forums_48.png', '24': 'images/forums_24 ...
# {'name': 'A Contour Advection Class Library in C++', 'labels': [], 'url': 'https://sourceforge.net/p/cspp/', 'preferred_support_tool': '', 'screenshots': [], 'forge': 'sourceforge', '_id': '514cc55fe88f3d0aabdec201', 'creation_date': '2006-08-02', 'socialnetworks': [], 'icon_url': None, 'summary': '', 'short_description': 'A C++ class library for Contour Advective methods in Fluid Mechanics', 'categories': {'developmentstatus': [{'fullpath': 'Development Status :: 2 - Pre-Alpha', 'fullname': '2 - Pre-Alpha', 'shortname': 'prealpha', 'id': 8}, {'fullpath': 'Development Status :: 1 - Planning', 'fullname': '1 - Planning', 'shortname': 'planning', 'id': 7}], 'database': [], 'environment': [], 'language': [{'fullpath': 'Programming Language :: C++', 'fullname': 'C++', 'shortname': 'cpp', 'id': 165}], 'audience': [{'fullpath': 'Intended Audience :: by Industry or Sector :: Science/Research', 'fullname': 'Science/Research', 'shortname': 'scienceresearch', 'id': 367}, {'fullpath': 'Intended Audience :: by Industry or Sector :: Education', 'fullname': 'Education', 'shortname': 'education', 'id': 360}, {'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers', 'id': 3}, {'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers', 'id': 2}], 'topic': [{'fullpath': 'Topic :: Scientific/Engineering :: Mathematics', 'fullname': 'Mathematics', 'shortname': 'mathematics', 'id': 98}], 'license': [{'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)', 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'id': 15}], 'os': [{'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All POSIX (Linux/BSD/UNIX-like OSes)', 'fullname': 'All POSIX (Linux/BSD/UNIX-like OSes)', 'shortname': 'posix', 'id': 200}], 'translation': []}, 'external_homepage': 'http://cspp.sourceforge.net', 'private': False, 'video_url': '', 'preferred_support_url': '', 'developers': [{'name': 'David Dunn', 'url': 'https://sourceforge.net/u/dcdunn/', 'username': 'dcdunn'}], 'tools': [{'name': 'summary', 'url': '/p/cspp/summary/', 'tool_label': 'Summary', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'summary', 'installable': False, 'sourceforge_group_id': 173898, 'mount_label': 'Summary'}, {'name': 'support', 'url': '/p/cspp/support/', 'tool_label': 'Support', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'support', 'installable': False, 'mount_label': 'Support'}, {'name': 'wiki', 'url': '/p/cspp/wiki/', 'tool_label': 'Wiki', 'icons': {'48': 'images/wiki_48.png', '24': 'images/wiki_24.png', '32': 'images/wiki_32.png'}, 'mount_point': 'wiki', 'installable': True, 'mount_label': 'Wiki'}, {'name': 'files', 'url': '/p/cspp/files/', 'tool_label': 'Files', 'icons': {'48': 'images/downloads_48.png', '24': 'images/downloads_24.png', '32': 'images/downloads_32.png'}, 'mount_point': 'files', 'installable': False, 'mount_label': 'Files'}, {'name': 'cvs', 'url': '/p/cspp/code/', 'tool_label': 'CVS', 'icons': {'48': 'images/code_48.png', '24': 'images/code_24.png', '32': 'images/code_32.png'}, 'mount_point': 'code', 'installable': False, 'mount_label': 'Code'}, {'name': 'reviews', 'url': '/p/cspp/reviews/', 'tool_label': 'Reviews', 'icons': {'48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'mount_point': 'reviews', 'installable': False, 'mount_label': 'Reviews'}, {'name': 'activity', 'url': '/p/cspp/activity/', 'tool_label': 'Tool', 'icons': {'48': 'images/admin_48.png', '24': 'images/admin_24.png', '32': 'images/admin_32.png'}, 'mount_point': 'activity', 'installable': False, 'mount ...
